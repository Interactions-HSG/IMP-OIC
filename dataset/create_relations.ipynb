# %%
import json

# %%
def import_file(path):
    with open(path, "r") as file:
        c = json.load(file)
        file.close()
        return c
    
def create_relations(annotations):
    """
    For every image, creates a list of triples in the form of (s, o, p)
    where s and o are the indexes of the annotations within the image and p is the index of the relation_category
    """

def get_bbox_relation(a, b):
    """
    Simple heuristic to return a rel_cat id to two bounding boxes
    """
    a_xyxy = xywh_to_xyxy(a)
    b_xyxy = xywh_to_xyxy(b)
    if box_similarity(a_xyxy, b_xyxy) > 0.6:
        return 0
    elif box_similarity(a_xyxy, b_xyxy) > 0.3:
        if a[1] > b[1]: # When a is below b
            return 1
        else:
            return 2
    else:
        
    return None
    
def xywh_to_xyxy(a):
    return (a[0] + a[2], a[0], a[1] + a[3], a[1])

def box_similarity(a, b):
    """
    Returns fraction of overlap with b to own box. 1 if perfect overlap, 0 if no overlap
    a == b == [xmax, xmin, ymax, ymin]
    """
    a_a = (a[0] - a[1]) * (a[2] - a[3])
    a_b = (b[0] - b[1]) * (b[2] - b[3])
    overlap = max(min(a[0], b[0]) - max(a[1], b[1]), 0) * \
              max(min(a[2], b[2]) - max(a[3], b[3]), 0)

    if a_a > a_b:
        return overlap / a_a
    else:
        return overlap / a_b

rel_cat = ["on", "below", "above"]

# %%
val = import_file("val.json")
rel = import_file("rel.json")
train = import_file("train.json")

# %%
image2ann = dict()
for a in train["annotations"]:
    image_id = a["image_id"]
    if image_id in image2ann.keys():
        image2ann[image_id].append(a)
    else:
        image2ann[image_id] = [a]

# %%
# For every image, examine their annotiosw
image_rel = dict()
for img, ann_list in image2ann.items():
    triples = []
    for i, a in enumerate(ann_list):
        for j, b in enumerate(ann_list):
            if i >= j:
                continue
            rel = get_bbox_relation(a["bbox"], b["bbox"])
            if rel:
                triples.append([i, j, rel])
    image_rel[img] = triples

# %%
xywh_to_xyxy(train["annotations"][0]["bbox"])
# Out:
# (404, 363, 628, 602)

# %%
image_rel
# Out:
# {'cl987t0fj1nt7074z8uli8uis': [[1, 5, 1]],
#  'cl987t0fa1nk7074zhwnv2j60': [],
#  'cl987t0fi1ns3074z9smhhmll': [[8, 9, 1],
#   [8, 10, 1],
#   [8, 11, 1],
#   [9, 10, 1],
#   [9, 11, 1],
#   [10, 11, 1]],
#  'cl987t0fb1nlz074z6v529i8b': [],
#  'cl74qgww3096g0878akhf4z3l': [],
#  'cl74qgwvo08oo08781tld9y6e': [[4, 5, 2]],
#  'cl74qgww809cw08789shn1vs4': [],
#  'cl5l1gjbb130r075jg4ucf16o': [[3, 10, 3], [6, 7, 3], [7, 8, 3], [8, 9, 1]],
#  'cl74qgwvj08jg0878gicoh01a': [],
#  'cl74qgwwd09ks08788lpb5s5c': [[0, 16, 3]],
#  'cl5l1gjbd136j075j7eai6k8x': [],
#  'cl74qgwvr08rc08787m6327u8': [],
#  'cl5l1gjbf13cv075jeg659iqc': [],
#  'cl5l1gjbg13fz075jgq7jcjcx': [[3, 4, 2], [4, 5, 2], [5, 6, 2]],
#  'cl74qgww909fg08786j2aedmz': [[4, 9, 2]],
#  'cl987t0fa1nk3074ze7h3che8': [],
#  'cl74qgwvj08jc08789rtoglys': [],
#  'cl987t0fi1nsr074zbycv32tb': [[5, 12, 1]],
#  'cl74qgwvo08os08780kde5isb': [[1, 2, 2]],
#  'cl987t0fi1nrz074z5z1bhkvs': [[0, 1, 1],
#   [0, 2, 1],
#   [0, 3, 1],
#   [1, 2, 1],
#   [1, 3, 1],
#   [2, 3, 1]],
#  'cl5l1gjbf13cr075j2xv7ayq3': [],
#  'cl987t0fa1nlb074zdhwn3s9u': [],
#  'cl74qgww3096c08786knx2ljk': [],
#  'cl5l1gjbb130n075jd2lqde4k': [[0, 3, 2], [6, 7, 3], [7, 8, 3], [8, 9, 3]],
#  'cl987t0fj1ntb074z24ihavgh': [[5, 6, 1]],
#  'cl74qgwvv08vs08787qh20rji': [],
#  'cl5l1gjb512kb075j22q0hxig': [[0, 15, 1],
#   [1, 16, 1],
#   [2, 17, 1],
#   [3, 23, 1],
#   [4, 13, 2],
#   [4, 19, 1],
#   [4, 27, 2],
#   [5, 22, 1],
#   [6, 21, 1],
#   [7, 10, 2],
#   [7, 26, 1],
#   [8, 24, 1],
#   [9, 20, 1],
#   [10, 25, 1],
#   [10, 26, 3],
#   [11, 28, 1],
#   [12, 30, 3],
#   [13, 19, 3],
#   [13, 27, 1],
#   [14, 29, 1],
#   [18, 31, 1],
#   [19, 27, 2]],
#  'cl74qgwwe09lo0878fhk1abfw': [[6, 7, 3]],
#  'cl74qgwvz090008784eoeewlg': [],
#  'cl74qgwwg09o40878h3ymhjat': [],
#  'cl74qgww1093k0878geakgrms': [],
#  'cl987t0fb1nmr074zdwyy9l78': [[1, 2, 1], [1, 3, 3], [2, 3, 1]],
#  'cl5l1gjb712p3075j0jw3aiwe': [],
#  'cl987t0f51nhv074z77kb3sxc': [[0, 1, 3], [0, 11, 2]],
#  'cl74qgwvz08zo08784julay2m': [],
#  'cl74qgww809e008785nn71q9u': [[1, 11, 2], [9, 12, 3]],
#  'cl5l1gjb712nn075j2gmq54y0': [],
#  'cl74qgwwd09lk0878d91jd0ot': [[14, 15, 3]],
#  'cl74qgww909ek08787nmq9k5m': [[0, 7, 3]],
#  'cl987t0fd1nof074z5e6h0pna': [[2, 3, 2]],
#  'cl5l1gjb512kr075j1yax8ktd': [[0, 17, 1],
#   [1, 22, 1],
#   [2, 21, 1],
#   [3, 18, 1],
#   [4, 19, 1],
#   [5, 20, 1],
#   [6, 23, 1],
#   [7, 26, 1],
#   [8, 29, 1],
#   [8, 30, 2],
#   [9, 30, 1],
#   [10, 27, 1],
#   [11, 31, 2],
#   [12, 28, 1],
#   [13, 14, 3],
#   [13, 16, 1],
#   [13, 25, 3],
#   [14, 16, 2],
#   [14, 25, 1],
#   [15, 24, 1],
#   [16, 25, 3]],
#  'cl74qgwvz08yc0878hoacc0lm': [],
#  'cl74qgwwg09o008782ub8d7wq': [],
#  'cl74qgww1093o0878bbym973t': [[0, 11, 3]],
#  'cl74qgwwd09lg08781u4gcp5i': [[14, 15, 3]],
#  'cl987t0fk1nvj074z23wdgs3a': [],
#  'cl74qgww6098o08784bcd9bae': [[0, 1, 2]],
#  'cl5l1gjbf13an075j26b648rh': [],
#  'cl74qgww709b00878cddz0pwl': [],
#  'cl74qgww709b40878f7ab3mgo': [],
#  'cl5l1gjbf13c7075jejz818od': [],
#  'cl74qgww0090g0878dzdv9lcp': [],
#  'cl74qgww909fw08788tsq8niu': [[3, 12, 3]],
#  'cl5l1gjbe13aj075j35py4z3u': [],
#  'cl74qgww909g80878bc1td8tm': [[5, 13, 2]],
#  'cl74qgwwd09kc0878g6zqgd67': [[8, 9, 2], [9, 10, 2]],
#  'cl74qgww709c00878cbbzfupt': [[1, 7, 2]],
#  'cl5l1gjbg13gb075j5es8cttk': [[5, 6, 3], [6, 7, 3]],
#  'cl5l1yjywd9ko074rf61y4ce7': [],
#  'cl74qgww0090c08782f2w7wzv': [],
#  'cl5l1gjbe13af075j9e9ng0x3': [],
#  'cl74qgww709aw08782ozq8ep8': [[13, 14, 3]],
#  'cl74qgwwd09kk0878frghbsig': [[6, 7, 2]],
#  'cl74qgwvz08zw08785jlb9lhf': [],
#  'cl5l1yjywd9lc074rbc2ufb7i': [],
#  'cl74qgwvg08eo08787alk5v0v': [[2, 3, 3]],
#  'cl74qgwvu08tw08784jq8bq5o': [],
#  'cl74qgwvk08kw087823bm9dq7': [[9, 10, 2]],
#  'cl74qgwvu08uk0878fmmohmk6': [],
#  'cl5l1gjbh13gz075j2lom68bh': [[5, 6, 2], [6, 12, 2], [7, 12, 3]],
#  'cl74qgww909ew08786xme2gh8': [[5, 8, 2]],
#  'cl74qgwvg08ek0878e5s30rg9': [[13, 14, 3], [14, 15, 3]],
#  'cl74qgwv8083w08780te01ind': [[15, 16, 3]],
#  'cl5l1gjbg13fn075j0the6kht': [[0, 1, 3], [2, 3, 3]],
#  'cl74qgwvt08ts08781oi3584s': [],
#  'cl74qgwvu08uo0878aum1bda1': [],
#  'cl5l1gjbg13fj075jf1elfmh7': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl5l1gjbi13jv075j7l4i9pzx': [],
#  'cl74qgwva08740878bgxh70xm': [[6, 7, 2], [8, 14, 2]],
#  'cl74qgwvg08eg087867x76k10': [[12, 14, 3]],
#  'cl5l1yjywd9lg074rh44qgyap': [],
#  'cl74qgwvi08h40878dvhxfxor': [[3, 4, 3]],
#  'cl74qgwva08700878c96lh201': [[13, 14, 2]],
#  'cl74qgwvo08og0878dufy28od': [],
#  'cl74qgwvk08k00878alrx8top': [[0, 1, 2]],
#  'cl74qgwvp08pg0878eejz2l1m': [],
#  'cl5l1gjbh13i3075j866879rl': [[15, 16, 3]],
#  'cl74qgwvz08zc08780jhiaw77': [],
#  'cl5l1gjbi13kz075j020bewk3': [[10, 11, 2]],
#  'cl74qgwvr08r408788ckz1s4r': [],
#  'cl5l1gjbi13k7075jfl73f8cf': [[0, 1, 3], [0, 12, 2], [1, 2, 1]],
#  'cl74qgwvi08h00878hqur9qkf': [[14, 15, 3]],
#  'cl74qgwvv08vw08784dlre1t3': [],
#  'cl74qgwvo08pc087848vpa8n4': [],
#  'cl74qgwv8084c0878enpl9vye': [[3, 4, 3], [4, 5, 3]],
#  'cl74qgwvr08rg08782lv17x73': [],
#  'cl74qgwvd08ck08785k7aaunk': [[2, 3, 3]],
#  'cl74qgwwh09qk0878cy0ddmmg': [],
#  'cl987t0fc1nn7074z66y2ah2j': [[0, 1, 3], [0, 2, 3], [1, 2, 1]],
#  'cl74qgwwj09sk0878hxxb2n5t': [[1, 10, 2]],
#  'cl74qgwwh09qg08780z3ob4ux': [],
#  'cl74qgwvd08cg0878grpk2foy': [[14, 15, 3]],
#  'cl987t0fi1nrv074zfffy9whu': [[8, 9, 3]],
#  'cl74qgwwf09no0878cmyf94i9': [],
#  'cl987t0f61ni3074zhdt83mbo': [],
#  'cl74qgwvd08cc08787zqacd4y': [[14, 15, 3]],
#  'cl987t0fc1no7074z9k0e6s9a': [[7, 8, 1]],
#  'cl74qgwvk08l8087809dv5tib': [],
#  'cl74qgwwa09hg0878gbod8nnq': [],
#  'cl74qgwvc08ak0878eumtay73': [[0, 1, 3]],
#  'cl5l1gjba12xb075jahce4f0c': [[3, 4, 1],
#   [3, 5, 2],
#   [3, 6, 2],
#   [4, 5, 1],
#   [4, 6, 2],
#   [5, 6, 1]],
#  'cl987t0fb1nm3074z7e120pgf': [],
#  'cl74qgwvo08o00878fz4j6t6o': [],
#  'cl74qgwwc09jw08782ng1d7fx': [[8, 9, 2], [10, 16, 2]],
#  'cl987t0f91njv074z697z8trr': [],
#  'cl74qgwvc08ag0878ggl41jh6': [[14, 15, 3]],
#  'cl74qgwvr08ro08782g6b4u40': [],
#  'cl74qgww809d00878bxush8en': [],
#  'cl74qgwwa09hc0878g5b3hqqh': [],
#  'cl74qgwvj08j80878fz1bgx27': [],
#  'cl5l1gjba12x7075jax9h0dxg': [[12, 13, 1],
#   [12, 14, 2],
#   [13, 14, 1],
#   [13, 15, 2],
#   [14, 15, 1]],
#  'cl74qgww309680878bjhy2ycw': [],
#  'cl74qgwwc09j0087857ik7rif': [],
#  'cl74qgwvz08zg0878fzzy62w5': [],
#  'cl74qgwvv08vk087863wi7m4c': [],
#  'cl74qgwvc08ac0878a7qwfzyp': [[14, 15, 3]],
#  'cl987t0fd1non074z6nr9ckk2': [[10, 11, 1]],
#  'cl5l1gjba12x3075j0cwo4uez': [],
#  'cl987t0fk1nvb074z9g9b8d7g': [],
#  'cl74qgwwc09k008783mpib4gw': [[0, 3, 2], [1, 2, 2], [1, 3, 3]],
#  'cl74qgwvk08l408782lhkbagl': [],
#  'cl987t0fa1nl7074zev2l0lb1': [],
#  'cl987t0f91njr074z3y0ig4sb': [],
#  'cl74qgwv80840087884rf1cjo': [[11, 13, 2]],
#  'cl5l1gjbd136n075jax7p1voc': [],
#  'cl74qgwvb088k0878gr2l1rvv': [[0, 16, 2], [15, 16, 3]],
#  'cl5l1gjbd1373075j5eq5an52': [],
#  'cl74qgwvb088g0878g0jrhrgs': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1gjbf13d3075j1h9r3vpx': [],
#  'cl5l1gjbg13fv075jebsk2a74': [[5, 6, 3], [5, 7, 2]],
#  'cl5l1gjbd1357075j6z9y6747': [],
#  'cl5l1gjbf13d7075j9jgr49yk': [],
#  'cl5l1gjbd1353075jbq06a3bk': [],
#  'cl5l1gjbb130j075jd4kmhegj': [[0, 2, 2], [4, 5, 3], [5, 6, 3], [6, 7, 1]],
#  'cl5l1yjywd9l4074r2c538mqd': [],
#  'cl74qgwvb088c08788kq2f2aq': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1gjbb130f075j9mqa4833': [[0, 2, 2], [4, 5, 3], [5, 6, 3], [6, 7, 1]],
#  'cl5l1yjywd9kw074rczaj34ey': [],
#  'cl5l1gjbd134z075jh9bsd4u8': [],
#  'cl74qgwvz08y808780u8f7l0o': [],
#  'cl5l1gjb912sr075j7qha5r70': [[9, 10, 3],
#   [10, 11, 1],
#   [10, 12, 3],
#   [11, 12, 1]],
#  'cl74qgww2094808781wj9ayc7': [],
#  'cl74qgww809ds08780ntt5ixe': [[4, 13, 2]],
#  'cl74qgwwd09kg0878gqlsbmnw': [[1, 2, 2], [2, 3, 2]],
#  'cl5l1gjb912sn075j4rtrdnal': [[11, 12, 3],
#   [12, 13, 1],
#   [12, 14, 3],
#   [13, 14, 1]],
#  'cl74qgww009080878hdd585oj': [],
#  'cl74qgww709as08789e2mcj4c': [],
#  'cl74qgwwb09iw08789b502xb8': [],
#  'cl74qgwvz08y40878563g4gjl': [],
#  'cl74qgww909f008788ehwda1k': [[1, 6, 2]],
#  'cl987t0f51nhn074z0pg4czcb': [[7, 8, 3]],
#  'cl987t0fn1o0b074z7jclcz80': [],
#  'cl5l1gjb812q3075jab993xz4': [],
#  'cl987t0fn1o07074z1efu7pt3': [],
#  'cl5l1gjbf13cb075j04iyd3su': [],
#  'cl987t0fn1o03074z3kn0bhk2': [],
#  'cl5l1gjbe13ab075j258584tp': [],
#  'cl987t0f51nhj074zh5u5068q': [[5, 6, 3]],
#  'cl987t0fn1nzz074zctj9ete2': [],
#  'cl5l1yjywd9ks074r0dmsdokl': [],
#  'cl987t0fn1nzv074zdugk0428': [],
#  'cl5l1gjb812q7075jh5e60br3': [],
#  'cl5l1gjb512kn075jaepedlun': [[0, 6, 3],
#   [0, 16, 1],
#   [1, 17, 1],
#   [2, 19, 1],
#   [3, 20, 1],
#   [4, 21, 1],
#   [5, 24, 1],
#   [6, 16, 2],
#   [6, 25, 1],
#   [7, 28, 1],
#   [8, 22, 1],
#   [9, 27, 1],
#   [10, 26, 1],
#   [11, 31, 2],
#   [12, 23, 1],
#   [13, 18, 1],
#   [14, 29, 1],
#   [15, 30, 1],
#   [16, 25, 3]],
#  'cl5l1gjb712nj075jdlrdhohv': [],
#  'cl987t0f51nhf074zglmzf2je': [[4, 5, 3], [5, 6, 3]],
#  'cl987t0fn1nzr074ze116ap23': [],
#  'cl5l1gjbe13a7075j95x9d91c': [],
#  'cl5l1gjb812pz075j64cp8k57': [],
#  'cl987t0fn1nzn074zbw110p67': [],
#  'cl74qgww1092s0878g8h90jve': [],
#  'cl5l1gjbh13hr075jbz8w359e': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgww5097o08782v4x2dy2': [[7, 8, 2]],
#  'cl74qgwvi08gw0878csovgbyj': [[13, 14, 2]],
#  'cl74qgwvt08to08787emy7hpr': [],
#  'cl74qgww709cc08783ksdbxpp': [[7, 13, 2]],
#  'cl74qgwwd09ko08781ej2hxxf': [[0, 1, 3], [1, 2, 3]],
#  'cl5l1yjyvd9j8074radds3xjj': [],
#  'cl74qgww909fo08786xm6fz2k': [],
#  'cl74qgwwf09nw0878azbiag4p': [],
#  'cl74qgww1092o087874fa22mk': [],
#  'cl5l1gjbg13ff075jb3y5c3gk': [[13, 14, 3], [15, 16, 3]],
#  'cl5l1yjywd9lk074r37y6hmhu': [],
#  'cl987t0fl1nwz074zejkl60jd': [],
#  'cl987t0fi1nrr074zhzwsh1iv': [[8, 9, 3]],
#  'cl987t0fl1nwv074zdhca74lz': [],
#  'cl5l1gjbb130b075jdsxkahhu': [[0, 2, 2], [5, 6, 3], [6, 7, 3]],
#  'cl5l1gjbd136r075j0cwr84s1': [],
#  'cl74qgww30964087805dxho61': [],
#  'cl987t0fj1ntf074z3pdudkic': [[7, 8, 1]],
#  'cl5l1gjbd134v075ja7xf1utf': [[3, 4, 3]],
#  'cl987t0fl1nwr074z73dv4njx': [],
#  'cl5l1gjbb1307075j87is6ilt': [[0, 2, 2], [5, 6, 3], [6, 7, 3]],
#  'cl987t0ff1nrn074z31u1gw3n': [[8, 9, 3]],
#  'cl74qgwvo08o808780vcab0xi': [],
#  'cl74qgwvk08l008788cen7989': [[13, 14, 3]],
#  'cl5l1gjbg13g3075jhqkk9ab4': [[0, 1, 2], [2, 3, 2]],
#  'cl74qgwwh09qc0878deuc2yys': [],
#  'cl74qgwwa09h408786tx86tgc': [],
#  'cl987t0fr1o2z074z3f2m6o9e': [],
#  'cl74qgwwd09lc0878epvzdqf8': [[14, 15, 3]],
#  'cl74qgwvz08yg08788wzn7c1g': [],
#  'cl987t0fk1nvn074zcac23x6s': [[9, 10, 2]],
#  'cl987t0f91njn074ze4m63yao': [],
#  'cl74qgwwj09so0878875p2427': [[3, 12, 2]],
#  'cl74qgwvy08y008781kkbh598': [],
#  'cl987t0fb1nm7074zai664a0u': [],
#  'cl74qgwwh09q80878bfuq6eo6': [],
#  'cl74qgwwa09h00878697ve7mv': [],
#  'cl74qgww1093g0878f4bu7oca': [],
#  'cl74qgwvj08j408782mq89edi': [[13, 14, 3]],
#  'cl74qgww909es0878630tg5p0': [[1, 13, 3]],
#  'cl74qgww00904087843mvch6d': [],
#  'cl74qgwvo08ow0878326q6umj': [],
#  'cl5l1gjbe13a3075je5be6mt4': [],
#  'cl987t0fb1nmn074zgb1m7a2s': [[5, 6, 3]],
#  'cl987t0f61ni7074zh1ru9oci': [[1, 2, 2]],
#  'cl74qgwwf09ns08789x18fzne': [],
#  'cl5l1gjbe139z075j0csidteu': [],
#  'cl5l1gjbi13jz075j09zm4bxx': [],
#  'cl5l1gjbf13cf075j4khf170w': [],
#  'cl5l1gjb712nv075j97nshd4n': [],
#  'cl74qgww709b808780jwee4fi': [],
#  'cl5l1gjb512kj075jc93z1rcs': [[0, 22, 1],
#   [1, 16, 1],
#   [2, 21, 1],
#   [3, 20, 1],
#   [4, 19, 1],
#   [5, 18, 1],
#   [6, 24, 1],
#   [7, 26, 1],
#   [8, 27, 1],
#   [9, 29, 1],
#   [10, 23, 1],
#   [11, 30, 1],
#   [11, 31, 2],
#   [12, 31, 1],
#   [13, 17, 1],
#   [14, 16, 2],
#   [14, 25, 1],
#   [15, 28, 1],
#   [16, 25, 3]],
#  'cl74qgwvt08tk08784swc3t7d': [],
#  'cl74qgwvg08ec08788x6a3qvw': [[14, 15, 3]],
#  'cl5l1gjb712nz075j4ugfat1h': [],
#  'cl74qgww709ao08786th020cb': [[13, 14, 3]],
#  'cl74qgwvu08us0878gcdv919g': [],
#  'cl5l1gjb712nf075j5033hie5': [],
#  'cl74qgwvg08e8087897pac9jy': [[14, 15, 3]],
#  'cl5l1gjbh13hz075jcgg184hk': [[13, 14, 3], [15, 16, 3]],
#  'cl5l1yjyvd9jc074r9ko3b0ku': [],
#  'cl74qgww5097s08787pvw2yai': [],
#  'cl5l1gjbi13k3075jd54ia5fp': [[8, 9, 3], [9, 10, 3], [10, 11, 1]],
#  'cl74qgwvd08c808783icoe3um': [[14, 15, 3]],
#  'cl5l1yjywd9lo074rg5jo32ki': [],
#  'cl74qgwva08780878d8mfbbea': [[0, 1, 3], [2, 3, 2]],
#  'cl5l1gjbg13fb075j2voa9ii6': [[14, 15, 3], [15, 16, 3]],
#  'cl74qgww1092k08782mb22j70': [],
#  'cl5l1gjbi13jr075j66s1ai8f': [],
#  'cl5l1yjyvd9jg074r1ckge5j3': [],
#  'cl5l1gjbb1303075jeehscz3i': [[0, 3, 3],
#   [0, 4, 3],
#   [3, 4, 3],
#   [5, 6, 3],
#   [6, 7, 1],
#   [6, 8, 3],
#   [7, 8, 1]],
#  'cl74qgwvi08gs0878cw660fnp': [[13, 14, 2]],
#  'cl74qgwvb0888087811qq12iz': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1gjba12wz075j6wih688u': [],
#  'cl74qgwvk08k808788268b8ow': [[1, 2, 2]],
#  'cl74qgwvc08a808787a8xel7n': [[14, 15, 3]],
#  'cl5l1gjbd136v075j6unnbf54': [],
#  'cl5l1gjba12wv075j8s880ks1': [],
#  'cl5l1gjbb12zz075j2f9v6o1h': [[0, 3, 3],
#   [0, 4, 3],
#   [3, 4, 3],
#   [5, 6, 3],
#   [6, 7, 1],
#   [6, 8, 3],
#   [7, 8, 1]],
#  'cl74qgwvb08840878auv53a0z': [[12, 16, 3], [14, 16, 2]],
#  'cl74qgwvc08a40878ez6vbw5d': [[14, 15, 3]],
#  'cl74qgwvj08j00878ep1wfkk6': [],
#  'cl5l1gjbd134r075jf1tj29yy': [],
#  'cl74qgwwf09nk0878a8sbf7wg': [[13, 14, 3]],
#  'cl5l1gjbf13db075jelki5dro': [],
#  'cl987t0f91njj074zcd1af25i': [],
#  'cl74qgwwc09k40878047z4483': [[0, 1, 2], [1, 2, 2]],
#  'cl987t0fj1ntn074zhtxg0jz3': [[3, 4, 3], [7, 8, 2]],
#  'cl987t0ff1nrj074z2yli4quq': [[8, 9, 3]],
#  'cl74qgwwa09gw0878ex5k4esg': [],
#  'cl74qgwwh09pw0878h4p71ugs': [],
#  'cl5l1gjbd134n075jczru6fs0': [],
#  'cl987t0fk1nvf074z7kz23rwg': [],
#  'cl74qgwv9085k08783hzk93hr': [[12, 13, 3], [13, 14, 3]],
#  'cl5l1gjb812sj075j52af9pnq': [[0, 2, 3],
#   [5, 6, 3],
#   [6, 7, 1],
#   [6, 8, 3],
#   [7, 8, 1]],
#  'cl74qgwv908640878309fh3l7': [[3, 4, 2], [5, 6, 2]],
#  'cl987t0ft1o5z074zhk2q2d2z': [],
#  'cl987t0fn1nzj074z3eg1eupv': [[0, 3, 3]],
#  'cl74qgwv908600878f86igvmk': [[4, 6, 3], [5, 7, 3]],
#  'cl5l1gjb812pr075j5ufveuo1': [],
#  'cl74qgww30960087836eq2srg': [],
#  'cl987t0fm1nzf074z0e2dcyz2': [[0, 3, 3]],
#  'cl74qgwva0868087853pta79f': [[0, 1, 2]],
#  'cl5l1gjb812sf075jewreakyz': [],
#  'cl987t0fm1nzb074z7jyqfwa8': [[1, 2, 3]],
#  'cl74qgww809d4087815lbfvjx': [],
#  'cl987t0fs1o5v074zgf5cgvxr': [[7, 8, 3]],
#  'cl74qgwvy08xw08785suqd62p': [],
#  'cl5l1gjb712pn075j31kucnvo': [],
#  'cl5l1gjb812sb075jdz0586nq': [],
#  'cl987t0fm1nz7074zgfo44on3': [[1, 2, 3]],
#  'cl74qgwwb09is08784m9d5jlr': [],
#  'cl74qgwv9085g087844r62pnw': [[13, 14, 3], [15, 16, 3]],
#  'cl5l1gjbe139v075jhxai43n6': [],
#  'cl74qgwvt08tg0878dqij28uj': [],
#  'cl5l1gjbg13g7075j57e19umw': [[4, 5, 3], [5, 6, 3], [6, 7, 3]],
#  'cl74qgwvz08zs08780fhe2ecv': [],
#  'cl5l1gjbe139r075jfkddehk8': [],
#  'cl5l1gjbe139n075j7ns22e66': [],
#  'cl5l1gjbh13hv075ja15e08au': [[15, 16, 3]],
#  'cl74qgwv8084808787vofepiu': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgww609ac0878a1uqd2r5': [[13, 14, 3]],
#  'cl5l1yjyvd9jk074rh7jvdsim': [],
#  'cl74qgww909g40878epb6hyfv': [[0, 9, 3]],
#  'cl987t0fl1nwn074z0w0desbr': [],
#  'cl987t0fl1nwj074zbnwmci9r': [[7, 8, 2]],
#  'cl74qgww1092g0878hymkgi5h': [],
#  'cl5l1gjb712nb075j9t7x5fsi': [],
#  'cl5l1gjb712nr075jhokafgq5': [],
#  'cl987t0fl1nwf074z6usth9t2': [],
#  'cl74qgwvi08go0878cpxk9s4k': [[14, 15, 3]],
#  'cl987t0f61nib074zcb0k4sgf': [],
#  'cl74qgwwf09ng08789b5wcwpg': [[13, 14, 3]],
#  'cl5l1yjywd9ls074r37tx07ab': [],
#  'cl987t0ff1nrf074z0cxc8lag': [],
#  'cl74qgwwj09ss0878fctwfl0u': [[3, 11, 2]],
#  'cl5l1gjbg13f7075jhzoy8a1m': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwwh09q40878943sczr2': [],
#  'cl987t0fj1ntr074z6td666gu': [[6, 7, 1]],
#  'cl5l1gjb512kf075j9g682nzt': [[0, 18, 1],
#   [1, 19, 1],
#   [2, 20, 1],
#   [3, 16, 1],
#   [4, 17, 1],
#   [5, 21, 1],
#   [6, 26, 1],
#   [7, 11, 2],
#   [7, 15, 2],
#   [7, 24, 1],
#   [8, 25, 1],
#   [9, 28, 1],
#   [10, 23, 1],
#   [11, 15, 1],
#   [12, 13, 2],
#   [12, 29, 1],
#   [12, 30, 2],
#   [13, 30, 1],
#   [14, 27, 1],
#   [15, 24, 3]],
#  'cl987t0f91njf074z0hf82fe3': [],
#  'cl74qgww3095w0878flubaqf2': [],
#  'cl74qgww909fc08785vx07nko': [[1, 9, 3]],
#  'cl987t0f91njb074z89lzdbzr': [],
#  'cl74qgwwd09l80878dbsn01nw': [[14, 15, 3]],
#  'cl74qgwvj08iw0878egnvcm4r': [],
#  'cl74qgwvr08r80878bkkr08z9': [],
#  'cl5l1gjbb12zv075je7ziaisv': [[0, 3, 3],
#   [0, 4, 3],
#   [3, 4, 3],
#   [5, 6, 3],
#   [6, 7, 1],
#   [6, 8, 3],
#   [7, 8, 1]],
#  'cl74qgww1093s08780c6u4our': [],
#  'cl74qgwvn08n80878aw1jcep9': [[5, 6, 3]],
#  'cl74qgwvo08p8087812oiel4o': [[5, 6, 2]],
#  'cl5l1gjbc134j075jben9fhop': [[3, 4, 3]],
#  'cl74qgwvy08xs08788jih36py': [],
#  'cl74qgwwa09gs08788u923q23': [],
#  'cl74qgwwd09l40878fu3z26bn': [[14, 15, 3]],
#  'cl5l1gjbb12zr075j94a38fqk': [[0, 2, 3],
#   [0, 3, 3],
#   [2, 3, 3],
#   [4, 5, 3],
#   [5, 6, 1],
#   [5, 7, 3],
#   [6, 7, 1]],
#  'cl74qgww20944087810kn6s1s': [[13, 14, 2]],
#  'cl74qgwvn08n40878bzypbdie': [],
#  'cl74qgwvz08yk08787cv244iu': [],
#  'cl5l1gjbd136z075j4i7fg4p6': [],
#  'cl74qgwv9085c0878a5wh7kk0': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvg08e40878by3qc3x2': [[14, 15, 3]],
#  'cl74qgwwf09n408780f25al1d': [[11, 12, 3]],
#  'cl987t0f61nif074z7goz8888': [[6, 7, 2]],
#  'cl5l1gjbe139j075j8cw27rls': [],
#  'cl987t0fb1nmj074z6x2ldl5a': [[0, 1, 3], [0, 8, 2]],
#  'cl74qgww709ak0878cxt36rx3': [],
#  'cl74qgww709bc08785fmn2gt0': [],
#  'cl5l1gjbe139f075j4v8kbzx3': [],
#  'cl987t0f61nhz074z7o73e09m': [[1, 11, 3]],
#  'cl5l1gjbe139b075jcql31l8e': [],
#  'cl74qgwwf09n008780eui89tk': [],
#  'cl5l1gjbf13cj075j2mm1fsmi': [],
#  'cl74qgwvd08c40878brijckys': [[14, 15, 3]],
#  'cl5l1gjbh13hn075j1kph4m9h': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwwf09nc0878c5tn531j': [[13, 14, 3]],
#  'cl74qgwvt08tc0878acg28wom': [],
#  'cl5l1yjyvd9jo074rhugn4vy5': [],
#  'cl74qgww5097w0878au1f2a3e': [[0, 1, 2]],
#  'cl74qgww1092c0878539i2g3g': [],
#  'cl74qgwvd08c0087861vf0r2o': [[14, 15, 3]],
#  'cl5l1gjb712n7075j813z522b': [],
#  'cl74qgwvu08uw08786vxm2h7d': [],
#  'cl74qgww2094c08780gejg1iu': [],
#  'cl5l1gjba12wr075jbmye83mg': [],
#  'cl74qgww809e40878hnu6462w': [],
#  'cl5l1gjba12wn075j7mk74v9f': [],
#  'cl74qgwvc08a0087817ry9fle': [[14, 15, 3]],
#  'cl5l1gjba12wj075j7ke18lvu': [],
#  'cl74qgww909eo0878cxua3pna': [[1, 6, 2]],
#  'cl987t0fb1nmb074z8pf08vnc': [],
#  'cl5l1yjywd9lw074r8ewlg1xk': [],
#  'cl74qgwvi08gk0878dm2114rp': [[11, 12, 3]],
#  'cl74qgwvo08o408788ow36y46': [[13, 14, 3]],
#  'cl987t0ff1nrb074zab0a5u5q': [],
#  'cl987t0fs1o5r074zdpd8fkko': [[3, 13, 3], [4, 5, 3]],
#  'cl5l1gjb812s7075jfh5rcqqk': [],
#  'cl5l1gjbb12zn075j584cejxb': [[0, 3, 3],
#   [2, 3, 3],
#   [4, 5, 3],
#   [4, 6, 3],
#   [5, 6, 1],
#   [5, 7, 3],
#   [6, 7, 1]],
#  'cl74qgwwa09go0878h8nq4b5o': [],
#  'cl74qgwvb08800878fa4mciqf': [[13, 15, 2], [14, 16, 3]],
#  'cl987t0f91nj7074z9hc9g87t': [],
#  'cl74qgwwh09q0087859wt5myk': [],
#  'cl74qgwwc09k808789p75d2mc': [[0, 1, 2], [1, 2, 2]],
#  'cl5l1gjb812s3075j2ucbcpav': [],
#  'cl5l1gjbg13f3075jb6q52tbu': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwvk08kc0878fudvhsyw': [],
#  'cl987t0fs1o5n074ze9ym5rml': [[5, 6, 3]],
#  'cl5l1gjbb12zj075jc6g7coju': [[0, 2, 3],
#   [3, 4, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl987t0fj1ntj074z417d8942': [[7, 8, 1]],
#  'cl987t0ff1nr7074z9nfubmsp': [],
#  'cl987t0fc1nn3074z6aiyg5yu': [[0, 1, 1], [0, 11, 2], [1, 11, 2]],
#  'cl74qgww2095s0878ayw53m7j': [],
#  'cl5l1gjbi13kb075jelc4aliw': [[6, 7, 3], [7, 8, 3], [8, 9, 3]],
#  'cl74qgwvs08s008786miq03tr': [],
#  'cl5l1gjb712pj075jhpni0g85': [],
#  'cl5l1gjbc134f075j9k5oh8b9': [],
#  'cl5l1gjbd135b075jfn1zet55': [],
#  'cl5l1gjb712pf075jbv7g5y5s': [],
#  'cl74qgww809d80878g82i9r9z': [],
#  'cl74qgwvn08n008781q8ngsp2': [],
#  'cl5l1gjbc134b075jgm2q503x': [],
#  'cl74qgww2095g087824kz0tsi': [],
#  'cl74qgwvv08vg0878fhwp1n07': [],
#  'cl74qgwva086c0878ekj0c0e5': [[0, 1, 2], [1, 2, 2]],
#  'cl5l1gjbe1397075j9mzzeggo': [],
#  'cl74qgwvj08io08784110240d': [[13, 14, 3]],
#  'cl74qgwvo08p008789v2q3xo2': [],
#  'cl5l1gjbe1393075jdzp184us': [],
#  'cl5l1gjbe138z075ja1zrd2rc': [],
#  'cl74qgwvy08xo0878bwiq8tg6': [],
#  'cl5l1gjbe138v075jd10qb4ej': [],
#  'cl987t0fl1nwb074z2usv6mz4': [],
#  'cl5l1gjbe138r075j1mnwcrht': [],
#  'cl5l1gjbe138n075j6o68hucg': [],
#  'cl5l1gjbe138j075jerr82v1g': [],
#  'cl5l1gjbe138f075jebkrfexn': [],
#  'cl5l1gjbe138b075jaqx54oc6': [],
#  'cl5l1gjbe1387075jdx6w8l8e': [],
#  'cl5l1gjbe1383075j3c9h0udf': [],
#  'cl74qgwv9085808785fd9h7fx': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl987t0fk1nw7074z5iri6cc6': [],
#  'cl5l1gjbe137z075j4tkwgjvv': [],
#  'cl74qgwwf09n80878cb4j0m5r': [[13, 14, 3]],
#  'cl987t0f61nij074z5i8b7zeq': [],
#  'cl987t0fa1nl3074z6d20c59s': [],
#  'cl74qgwwa09gc0878dy2uh8sx': [[8, 10, 2]],
#  'cl74qgwvt08t80878h2or28cp': [],
#  'cl987t0fm1nyv074z3rr71e29': [[2, 3, 3], [8, 9, 2]],
#  'cl987t0fd1noj074zbbpjgi9o': [[2, 3, 1]],
#  'cl74qgww809eg0878ccsg14rs': [[0, 9, 3]],
#  'cl987t0fm1nz3074zgxw99xih': [[2, 3, 3]],
#  'cl5l1gjbh13hj075jf9ga5ekd': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl5l1yjyvd9js074r9z2uajmy': [],
#  'cl74qgww609ag08781negdpu3': [],
#  'cl74qgww1092808784erh9stp': [],
#  'cl5l1gjb712o3075j7bisc64w': [],
#  'cl5l1gjb612n3075j6mwac585': [],
#  'cl74qgww1093c0878abudggcq': [],
#  'cl74qgwvi08gg0878eo9mdsm8': [[14, 15, 3]],
#  'cl5l1yjywd9m0074r6wti92mm': [],
#  'cl74qgwwd09l008784n2024gb': [[14, 15, 3]],
#  'cl5l1gjbg13ez075jb54u6tfb': [[13, 14, 3], [15, 16, 3]],
#  'cl987t0ff1nr3074zbhiu53bg': [],
#  'cl74qgwwd09kw08784s1a2b32': [[14, 15, 3]],
#  'cl74qgwvg08e00878f8qebdvy': [[12, 13, 3], [13, 14, 3]],
#  'cl987t0f91nj3074z6fmx6o61': [],
#  'cl74qgwwa09gk087868eaaxxc': [],
#  'cl74qgwwh09ps087887wc850s': [],
#  'cl74qgwwj09sw0878fhd75fq7': [[3, 12, 2]],
#  'cl74qgwvg08dw0878hdns1ucw': [[14, 15, 3]],
#  'cl74qgwva086g08788s8k7zuy': [[0, 6, 2]],
#  'cl74qgww2095o087890koeufr': [],
#  'cl987t0f91niz074zf3kv1fcb': [],
#  'cl74qgwv908540878dxsweiif': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwvj08is0878d6ch953y': [[13, 14, 3]],
#  'cl74qgwvn08nc08783p8bf3xq': [],
#  'cl74qgwvs08rw08783vt14kj0': [],
#  'cl74qgwvy08xk0878cmyd5pa5': [],
#  'cl5l1gjbc1347075j2u2l7nzt': [],
#  'cl74qgwvn08mw08784ozv95w5': [],
#  'cl5l1gjbd135f075jh2idhpf3': [],
#  'cl74qgwvj08ik0878fxx62do9': [[13, 14, 3]],
#  'cl74qgwvh08es0878fcxjc2ro': [[3, 4, 3]],
#  'cl5l1gjbe137v075j3jpo2ag1': [],
#  'cl5l1yjyxd9ng074rdwm1gqc9': [],
#  'cl74qgwva087c0878abmbbu34': [[4, 6, 3], [5, 6, 2]],
#  'cl74qgwv8083o0878cl3xa6em': [[5, 6, 2], [7, 8, 2]],
#  'cl5l1gjbe137r075j1ljl9jub': [],
#  'cl74qgww809ec08782n5b32f1': [[0, 9, 3]],
#  'cl5l1yjyxd9nc074r4acl97ul': [],
#  'cl5l1gjbe137n075j8d1561uy': [],
#  'cl5l1yjyxd9n8074r5yxu5uuw': [],
#  'cl5l1gjbd137j075j1sjf7j6v': [],
#  'cl74qgwv8083s08780r187kg1': [[0, 15, 2]],
#  'cl5l1yjyxd9n4074r9ymdcz8w': [],
#  'cl5l1gjbh13jn075jdqhs0w2q': [[0, 1, 3], [0, 13, 3], [1, 2, 3]],
#  'cl74qgww609a80878bx8k5ex4': [[13, 14, 3]],
#  'cl74qgwvb087w0878ajxncibs': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvt08t40878f5pdhlh3': [],
#  'cl5l1gjbb12zf075j31pc096g': [[0, 2, 3],
#   [3, 4, 3],
#   [3, 5, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl5l1gjbf13cn075jhzhy7zno': [],
#  'cl74qgwvc089w0878g16t85ie': [[14, 15, 3]],
#  'cl74qgwvd08bw0878eya66hvj': [[14, 15, 3]],
#  'cl5l1gjbb12zb075j7vo22obs': [[0, 2, 3],
#   [3, 4, 3],
#   [3, 5, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl74qgww709bg08784uwvepfu': [],
#  'cl74qgwvb087s0878d3k4apao': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvc089s08787ujx0fs1': [[14, 15, 3]],
#  'cl5l1gjbb12z7075j3cm53grz': [[0, 2, 3],
#   [3, 4, 3],
#   [3, 5, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl74qgwvd08bs08788l8602en': [[14, 15, 3]],
#  'cl74qgww609a408786wrv1ojg': [[13, 14, 3]],
#  'cl74qgwwj09sc087867jkdqqf': [[8, 13, 2]],
#  'cl987t0fc1nnb074zcz6f48qy': [[0, 1, 1], [0, 2, 2], [1, 2, 1]],
#  'cl5l1gjbh13hf075jb60l0kf4': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgww709c80878gpz3cs82': [[0, 9, 3]],
#  'cl5l1yjyvd9jw074r5c3zd6vx': [],
#  'cl74qgww909fs0878hupt2aw8': [],
#  'cl987t0fc1no3074z1775as0f': [[1, 2, 1]],
#  'cl74qgww109240878hnmxgzdy': [],
#  'cl74qgww809e808789mxpb1ww': [[1, 10, 3]],
#  'cl74qgww109380878amlh2do9': [],
#  'cl74qgww5098008780hgv1crf': [[0, 1, 2]],
#  'cl74qgww5097k0878ejp72756': [],
#  'cl74qgwwj09s8087822brep8v': [[0, 9, 3]],
#  'cl5l1yjywd9k0074rfqjt3f7j': [],
#  'cl74qgwvh08gc0878dayq2idd': [[14, 15, 3]],
#  'cl5l1gjb812rz075jg1kg77zf': [],
#  'cl5l1yjywd9m4074re1o6748w': [],
#  'cl987t0fs1o5j074z9e0qenj4': [[7, 8, 3], [8, 9, 3]],
#  'cl5l1gjba12wf075j069e9fx9': [],
#  'cl5l1gjb612mz075j4bzgh8lm': [],
#  'cl5l1gjb812rv075jhrcya5hw': [],
#  'cl5l1gjba12wb075j5wxabvqv': [],
#  'cl5l1gjbg13ev075j8uut4guk': [],
#  'cl987t0fs1o5f074zfeq63h3g': [[6, 7, 3], [8, 9, 3]],
#  'cl5l1yjywd9m8074r64tp87ad': [],
#  'cl5l1gjb812rr075jedxeh9ct': [],
#  'cl74qgwvh08g80878ddcjdxeu': [[14, 15, 3]],
#  'cl5l1gjba12w7075j1h1obk79': [],
#  'cl987t0fj1ntv074zc5zrbu4y': [],
#  'cl74qgwvz08yo0878do4u6mp0': [],
#  'cl987t0fb1nmf074zdyts20ch': [[4, 5, 2]],
#  'cl74qgwvy08xg0878ec8bepen': [],
#  'cl987t0ff1nqz074zhua81ave': [],
#  'cl987t0f91niv074zg15cgtlt': [],
#  'cl74qgww2095k08781spibcfx': [],
#  'cl74qgww809dg08789kr86x3j': [],
#  'cl74qgwv908500878fetof3g6': [[13, 14, 3], [15, 16, 3]],
#  'cl5l1gjb712pb075j5uoxbkzf': [],
#  'cl74qgwwa09gg08786ig5ddiw': [[0, 9, 3]],
#  'cl74qgwwh09po08786ver52y2': [[0, 8, 3]],
#  'cl5l1gjb712p7075jf8b5ffeb': [],
#  'cl74qgwvl08ms08785z2f0er9': [],
#  'cl5l1gjbi13kf075j0qcw2opm': [[0, 1, 3], [0, 3, 2], [1, 2, 3]],
#  'cl5l1gjbh13jj075jbh6bckjt': [[13, 14, 3], [14, 15, 3]],
#  'cl5l1gjbc1343075jhv8c6os3': [],
#  'cl987t0fm1nyz074z799rb3c4': [[2, 3, 2]],
#  'cl987t0fk1nw3074zex909g5a': [],
#  'cl74qgwva086w0878ab7f04ry': [[0, 1, 3]],
#  'cl987t0fm1nyr074zd71t3znn': [[0, 1, 1],
#   [0, 2, 1],
#   [0, 3, 3],
#   [1, 2, 1],
#   [1, 3, 1],
#   [2, 3, 1]],
#  'cl74qgwvo08p40878ewi329ke': [],
#  'cl5l1gjbc133z075j72buct3f': [],
#  'cl987t0fk1nvz074zd8c3caki': [],
#  'cl74qgwvj08ig0878fhjm5mqf': [[13, 14, 3]],
#  'cl987t0fc1nnf074z8wrkbcfq': [[4, 5, 1], [4, 6, 1], [5, 6, 1]],
#  'cl5l1gjbd137f075jd56rcjxx': [],
#  'cl74qgwwf09mw08785a4h011f': [],
#  'cl74qgwwj09s408787xnjh3i2': [[0, 9, 3]],
#  'cl5l1gjbd137b075jfbcr00ne': [],
#  'cl74qgww609a008786apxfkrj': [[13, 14, 3]],
#  'cl74qgww709cg087808j2ggxk': [],
#  'cl74qgwvt08t008788w2r8qj9': [],
#  'cl5l1gjbh13hb075j6mc1dmkv': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwvv08v008789wyub26m': [],
#  'cl74qgww1092008781sukd9qe': [],
#  'cl74qgww109340878ff1kfz05': [],
#  'cl74qgwwc09j808784hq85y4o': [],
#  'cl5l1yjywd9k4074r6gya3drc': [],
#  'cl74qgwv8084g0878donnde50': [[13, 16, 3], [15, 16, 2]],
#  'cl74qgwva086s087804ygfn6i': [[8, 9, 2], [9, 10, 2]],
#  'cl74qgwv8083808786u8weyqr': [[13, 14, 2]],
#  'cl5l1gjb712o7075j30jzacfz': [],
#  'cl74qgwvk08k40878ckeucu4o': [[1, 2, 2]],
#  'cl987t0fj1ntz074zc4xh5w7f': [],
#  'cl987t0ff1nqv074zfiea46q1': [],
#  'cl74qgwvr08rk0878e5ij79xd': [],
#  'cl987t0f91nir074zfdm88gp0': [],
#  'cl5l1gjb612mv075jd32r8qpj': [],
#  'cl5l1gjbg13er075j0t6qamsp': [],
#  'cl5l1yjywd9mc074r57agfj31': [],
#  'cl74qgwvh08g408782rgecbup': [[14, 15, 3]],
#  'cl74qgww909f8087804jc8mol': [[0, 9, 3]],
#  'cl74qgwvg08ds0878bem8bj0i': [[14, 15, 3]],
#  'cl74qgwwh09pk087846gd3diq': [[0, 8, 3]],
#  'cl74qgwwj09t00878g69m5a42': [],
#  'cl74qgwvn08ng0878ev9d7t4b': [],
#  'cl74qgww2095c0878gtgn9dxy': [],
#  'cl74qgwvl08mo08780q2oegte': [],
#  'cl74qgwvg08do08784dg69h0q': [[14, 15, 3]],
#  'cl5l1gjbh13jf075j9gr3dkgl': [[12, 13, 3], [13, 14, 3], [14, 15, 3]],
#  'cl74qgwvy08xc0878ereu9jex': [],
#  'cl5l1gjbc133v075jc02davbw': [],
#  'cl74qgwvd08bo0878cr872cqs': [[14, 15, 3]],
#  'cl5l1gjbd135j075j6hx3bswy': [],
#  'cl74qgwva086k08784v3kcnyg': [[0, 1, 2], [1, 2, 2]],
#  'cl5l1gjbc133r075jfato999e': [],
#  'cl74qgwvj08ic087864hx5swc': [[13, 14, 3]],
#  'cl74qgwv808440878fxff64f6': [[15, 16, 3]],
#  'cl74qgwv9084w0878epusff31': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvt08sw0878bcdebs5d': [],
#  'cl5l1gjbb12z3075jgjoi5avt': [[0, 3, 3],
#   [1, 2, 3],
#   [1, 4, 3],
#   [2, 4, 1],
#   [2, 6, 3],
#   [4, 6, 1]],
#  'cl5l1gjbh13h7075j0pcu3j3q': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1gjbd1377075jc0ka3fpx': [],
#  'cl5l1gjbb12yz075j3ru1gkn0': [[0, 2, 3],
#   [3, 4, 3],
#   [3, 5, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl5l1yjywd9k8074r9xam4sqr': [],
#  'cl5l1gjbb12yv075jb81r5rrh': [[0, 2, 3],
#   [3, 4, 3],
#   [3, 5, 3],
#   [4, 5, 1],
#   [4, 6, 3],
#   [5, 6, 1]],
#  'cl74qgww809dw08781pfv4nfd': [[0, 4, 3]],
#  'cl5l1gjbb12yr075jdsrd9u8l': [[0, 2, 3],
#   [3, 4, 1],
#   [3, 5, 3],
#   [3, 6, 3],
#   [4, 5, 1],
#   [4, 6, 1],
#   [5, 6, 1]],
#  'cl74qgwvz08zk0878a0p9gpre': [],
#  'cl74qgwvt08ss08784hv21h1o': [],
#  'cl74qgww0091w0878037g4bni': [],
#  'cl5l1gjb812rn075j052p4nk8': [],
#  'cl74qgwvc089o0878a9fn7wbk': [[14, 15, 3]],
#  'cl5l1gjba12w3075jatvff52b': [],
#  'cl74qgwwj09s00878gbeh7rsp': [[0, 9, 3]],
#  'cl74qgww6099w08780gex2vip': [[13, 14, 3]],
#  'cl5l1gjb812rj075j5zs9hwk0': [],
#  'cl74qgww709bk08787rvfd3x5': [],
#  'cl5l1gjba12vz075j4n949kfv': [],
#  'cl74qgww509840878f0af6jzh': [],
#  'cl987t0fc1nnn074zezte7wvq': [[3, 4, 2], [5, 6, 1], [5, 7, 1], [6, 7, 1]],
#  'cl74qgwvc089k08789zzg60dy': [[15, 16, 3]],
#  'cl987t0ff1nqr074z9tio1inp': [],
#  'cl74qgwva087o0878axb6c89l': [[12, 13, 3], [13, 15, 3], [15, 16, 3]],
#  'cl74qgww109300878gyy5ai61': [],
#  'cl74qgwv808340878c4bmfypc': [[2, 3, 3]],
#  'cl5l1gjb612mr075j3g2qc6nb': [],
#  'cl987t0fj1nu3074z3num72dz': [],
#  'cl5l1gjb612mn075j1g2xfmle': [],
#  'cl5l1gjb712ob075j71cc84dq': [],
#  'cl74qgwv7083008783ihb0g2u': [[13, 14, 2]],
#  'cl987t0ff1nqn074z3mzrazlf': [],
#  'cl5l1gjb612mj075jbupcej4n': [],
#  'cl74qgwvv08vo087877hw4pbf': [],
#  'cl987t0fm1nyn074zdfnre7gq': [[0, 1, 1],
#   [0, 2, 1],
#   [0, 3, 3],
#   [1, 2, 1],
#   [1, 3, 1],
#   [2, 3, 1]],
#  'cl74qgwvz08z808783lbd0f3x': [],
#  'cl987t0fs1o5b074z75tm5oe4': [],
#  'cl987t0fa1nkz074zeur3af45': [],
#  'cl74qgwvr08qs08780kei5ssc': [],
#  'cl987t0fm1nyj074z1mofgnvq': [],
#  'cl987t0fs1o57074zbng79oz9': [],
#  'cl74qgww2093w08780vq15zri': [],
#  'cl74qgwvh08g00878esen77j3': [[14, 15, 3]],
#  'cl74qgwvq08qo0878dsqe87oo': [],
#  'cl987t0fm1nyf074z74uqc1wz': [],
#  'cl987t0f81nin074zexgedah2': [],
#  'cl74qgwv9085w08788ctyhnfq': [[7, 8, 3], [8, 9, 3], [9, 10, 3]],
#  'cl74qgww2095808789tz2ab9b': [[13, 14, 2]],
#  'cl5l1gjbg13en075jfz5whir8': [],
#  'cl5l1yjywd9mg074re01l74hj': [],
#  'cl74qgwv9085s08782azsgc2a': [[14, 15, 3], [15, 16, 3]],
#  'cl74qgwv9084s0878g8a91xlp': [[13, 14, 3], [15, 16, 3]],
#  'cl74qgwvy08x80878fynj5itu': [],
#  'cl74qgwwh09pg087849c26p1e': [],
#  'cl74qgwvz08ys0878fwovhpoi': [],
#  'cl987t0fd1nob074z3taocic8': [[5, 6, 1]],
#  'cl74qgwvl08mk0878csaidfhi': [[13, 14, 3]],
#  'cl74qgwvy08x408787bvy00de': [],
#  'cl987t0fc1nmz074z327f2wjw': [[4, 5, 1], [4, 6, 3], [5, 6, 1]],
#  'cl74qgwwf09ms0878els7ezc6': [[13, 14, 3]],
#  'cl5l1gjbc133n075jgxon3cce': [],
#  'cl5l1gjbf13cz075j5kldb449': [],
#  'cl74qgwwf09mo087888dyea5v': [[13, 14, 3]],
#  'cl5l1gjbc133j075jfdnd8wc3': [],
#  'cl5l1gjbh13jb075jcj4wamuo': [[12, 13, 3], [13, 14, 3], [14, 15, 3]],
#  'cl74qgww909g00878a067fz21': [[0, 9, 3]],
#  'cl74qgwvv08v408789enhgh2b': [],
#  'cl5l1gjbi13kj075jak3bhvkz': [[0, 1, 2], [1, 2, 2], [2, 3, 2]],
#  'cl74qgww6099s0878hmix3e1z': [],
#  'cl74qgwvt08so08786xao1m9j': [],
#  'cl5l1gjbh13j7075jgysja9jh': [[12, 13, 3], [13, 14, 3], [14, 15, 3]],
#  'cl987t0fk1nvr074z4c2ghntq': [[4, 5, 2]],
#  'cl74qgww0091s0878hga75iyg': [],
#  'cl74qgww1092w0878ci1se543': [],
#  'cl5l1gjbh13h3075j5633hb33': [[11, 12, 3], [12, 13, 3], [13, 14, 3]],
#  'cl74qgwwi09rw0878gldd3rul': [],
#  'cl5l1gjb612mf075jh93x0baf': [],
#  'cl5l1yjywd9kc074rgslk2hpm': [],
#  'cl5l1gjb612mb075j70k41jxt': [],
#  'cl5l1gjb612kz075jesolgx9x': [],
#  'cl74qgwvj08i80878d9er8zu2': [[13, 14, 3]],
#  'cl74qgww0091o0878du6jfzht': [],
#  'cl5l1gjb612m7075j4r7dbeyi': [],
#  'cl5l1gjbg13ej075j2dcteczr': [],
#  'cl5l1yjyxd9mo074rajra8sh5': [],
#  'cl74qgwvv08w00878dii78f5r': [],
#  'cl74qgwvp08qk0878d0uscpxr': [],
#  'cl74qgwvd08bk0878eyj785f4': [[14, 15, 3]],
#  'cl987t0ff1nqj074zdt26hdh5': [],
#  'cl74qgwvl08mg08782ucr8zlr': [],
#  'cl987t0fj1nu7074z2wz54569': [],
#  'cl74qgwvd08bg08787qj6byc8': [[14, 15, 3]],
#  'cl74qgwv9085o08787f6w0sil': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvn08nk0878378nczl0': [],
#  'cl74qgwva086o0878dgmq4scn': [[0, 1, 2]],
#  'cl74qgww809dc0878bkwm1m1v': [],
#  'cl74qgwvg08dk0878dpji7o3c': [[14, 15, 3]],
#  'cl74qgww209540878axbg1egd': [[13, 14, 2]],
#  'cl74qgwwb09io0878bq4m4cyr': [],
#  'cl74qgwvk08kg08783ddy8wuq': [],
#  'cl74qgwvc089g08785x02ce0w': [[14, 15, 3], [15, 16, 3]],
#  'cl74qgwvh08fw08781yu62ldq': [[14, 15, 3]],
#  'cl74qgwvg08dg08789mxp36dj': [[14, 15, 3]],
#  'cl74qgwwc09jc0878bckt57oe': [[0, 3, 2], [2, 3, 3], [2, 4, 2]],
#  'cl5l1gjbb12yn075j4c4s8edm': [[0, 3, 3],
#   [2, 3, 3],
#   [5, 6, 1],
#   [5, 7, 3],
#   [6, 7, 1]],
#  'cl74qgwwh09pc0878a7qo7bci': [],
#  'cl5l1gjbc133f075j9ie03yev': [],
#  'cl5l1gjbd135n075jhn5779k6': [],
#  'cl5l1gjba12vv075jff9c88yw': [],
#  'cl74qgww2094008786oyk2875': [],
#  'cl5l1gjba12yj075j5duaccig': [[3, 4, 3], [6, 7, 1]],
#  'cl5l1gjbc133b075j0v6v93xe': [],
#  'cl74qgwwj09t408781dzh9g8k': [],
#  'cl5l1yjywd9l0074r0bhtcu56': [],
#  'cl5l1gjbc1337075j49ssenp0': [],
#  'cl5l1gjba12yf075j9gbben4a': [[3, 4, 3], [7, 8, 3]],
#  'cl5l1gjba12vr075j1spb2ent': [],
#  'cl74qgwvy08x00878gik0a1n6': [],
#  'cl5l1gjbc1333075j0s3k69l5': [],
#  'cl74qgwvs08sk0878hvph17h4': [],
#  'cl5l1gjba12yb075j9i76fxyg': [[5, 6, 3],
#   [10, 11, 3],
#   [10, 12, 3],
#   [11, 12, 1]],
#  'cl74qgwwg09p808786uk4cqs8': [],
#  'cl5l1gjba12vn075j0tqj4g83': [],
#  'cl5l1gjb812rf075j4r253ug4': [],
#  'cl74qgww6099o08782lec4wzx': [],
#  'cl5l1gjb812rb075j3u9jbgq4': [],
#  'cl74qgwvi08i40878fngd66pb': [],
#  'cl5l1gjbh13j3075jhpiifvbo': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwwi09rs08784hiv1gf7': [],
#  'cl74qgwva087k0878e7bi4bcc': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl5l1gjb512kv075j8oo7almt': [],
#  'cl987t0fm1nyb074z1ydh1uv3': [],
#  'cl987t0fc1nnr074z7dup1dbd': [[3, 4, 2], [5, 6, 1], [6, 7, 2]],
#  'cl74qgwv8083c0878ftlgaey2': [[0, 1, 3], [2, 3, 3]],
#  'cl987t0fc1nnz074z2ham6ne3': [[2, 4, 1]],
#  'cl987t0fm1ny7074ze6ts8vjn': [[5, 6, 2]],
#  'cl74qgww0091k08782b3s1kly': [],
#  'cl5l1yjyyd9r0074r56pf73ds': [],
#  'cl74qgwwi09ro08789pfp10kj': [],
#  'cl74qgww6098s08789fhoek78': [[7, 8, 3]],
#  'cl987t0fs1o53074z9a2ufxwc': [[1, 2, 3], [2, 3, 3], [5, 8, 3]],
#  'cl987t0ff1nqf074zba09h39h': [],
#  'cl5l1yjyxd9ms074r1p3kdofh': [],
#  'cl5l1gjbg13ef075j3w6572uu': [],
#  'cl987t0fj1nub074zhsz3b3da': [],
#  'cl987t0fs1o4z074ze6st562o': [[2, 3, 3], [5, 8, 3]],
#  'cl74qgww5097g087878h8c1q9': [[13, 14, 3]],
#  'cl987t0fe1nqb074z6zvq1se4': [],
#  'cl5l1gjb712of075j37svgrxo': [],
#  'cl5l1gjb612m3075jacmmfj5s': [],
#  'cl5l1gjb612lz075jbequ1k0n': [],
#  'cl74qgwvp08qg08786yy1hrob': [],
#  'cl74qgwv9084o08781u5i7ykv': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgwvo08oc08782ndc4xw1': [],
#  'cl74qgww909f40878hz4994ki': [[0, 9, 3]],
#  'cl74qgwwe09mk08782z95c91z': [[13, 14, 3]],
#  'cl74qgwwb09ik08789hpv8p33': [],
#  'cl74qgww2095008788cqbgsfq': [[13, 14, 2]],
#  'cl74qgwwe09mg0878enh76tra': [],
#  'cl74qgwvh08fs08787xrlda0u': [[14, 15, 3]],
#  'cl74qgwwg09p40878539wacoc': [],
#  'cl74qgwwc09j40878f3ak02ld': [],
#  'cl74qgwvl08mc0878anpse854': [],
#  'cl74qgww709bo0878e2imc8a7': [[0, 1, 2], [5, 14, 2]],
#  'cl5l1gjbc132z075j7qb66byl': [],
#  'cl5l1gjbc132v075j28tq1ro0': [],
#  'cl5l1gjbd135r075jew7i1fxh': [],
#  'cl5l1gjbc132r075j893n7sd4': [],
#  'cl74qgww6099k087800oo28y5': [[13, 14, 3]],
#  'cl74qgwvz08yw0878ar8j8ofc': [],
#  'cl74qgwvj08jk0878dys48fh2': [],
#  'cl5l1gjbc132n075j6835gwhc': [],
#  'cl74qgwvy08ww08785yk65yw2': [],
#  'cl74qgwvi08i0087823ry0yeq': [[14, 15, 3]],
#  'cl5l1gjbc132j075jcxzmgvfu': [],
#  'cl5l1gjbc132f075jejta4u9a': [],
#  'cl5l1gjbf13df075jb6rpbpy5': [],
#  'cl74qgww5098808784zgbd74o': [],
#  'cl5l1gjbg13gf075j7cm7at22': [[4, 5, 3], [5, 6, 3], [6, 7, 3]],
#  'cl5l1gjbg13gj075j258w9jfm': [[0, 1, 2], [1, 2, 2]],
#  'cl74qgwvv08v808784h6mb4qa': [],
#  'cl5l1gjbi13kn075jfy3fgs4o': [[0, 1, 2], [1, 2, 2], [2, 3, 2]],
#  'cl74qgww0091g08785065cl59': [],
#  'cl74qgww709c408784w1e2g9i': [[0, 9, 3]],
#  'cl5l1gjbf13bz075j2fkx4y18': [],
#  'cl74qgwvs08sg0878h57vdn0g': [],
#  'cl5l1gjbh13iz075j8bjw57vc': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1yjyyd9qw074rce2o82zf': [],
#  'cl74qgww809ck08786as6etfv': [[0, 1, 2]],
#  'cl74qgwvg08dc0878edqd9xqr': [[13, 14, 3], [14, 15, 3]],
#  'cl5l1yjyyd9qs074r0xsghamj': [],
#  'cl74qgww5097c087834kgcewo': [[13, 14, 3]],
#  'cl5l1yjyyd9qo074rd1gkh75g': [],
#  'cl5l1yjywd9mk074rb205di9g': [],
#  'cl5l1gjb612lv075jcyeod2zu': [],
#  'cl74qgww2094w08782v8oc2zg': [[13, 14, 2]],
#  'cl5l1gjbg13eb075jc97g6xdv': [],
#  'cl74qgwvd08bc08785luhd1io': [[14, 15, 3]],
#  'cl5l1gjb712oj075jdcp29a3g': [],
#  'cl74qgww809dk08781jnt60f1': [],
#  'cl5l1gjb612lr075j2a5b60ow': [],
#  'cl987t0fj1nuf074zfz009s46': [],
#  'cl987t0fe1nq7074z9c0t667m': [],
#  'cl74qgwwi09rk08783sjbhip6': [],
#  'cl5l1gjb612ln075j71jh9fph': [[1, 2, 2]],
#  'cl74qgwvp08qc08785n087cjo': [],
#  'cl74qgwvd08b808783orcfo5g': [[14, 15, 3]],
#  'cl74qgwvv08w40878cvimfaxx': [],
#  'cl5l1yjyxd9mw074r20wsddjy': [],
#  'cl74qgwv9084k0878h1357p3k': [[14, 15, 3], [15, 16, 3]],
#  'cl74qgwvb089c087838vz3a6v': [[15, 16, 3]],
#  'cl5l1gjba12y7075jb8qr4puu': [[11, 12, 3],
#   [11, 13, 3],
#   [11, 14, 3],
#   [12, 13, 1],
#   [12, 14, 1],
#   [13, 14, 1]],
#  'cl74qgwvh08fo0878421v2q0i': [[14, 15, 3]],
#  'cl74qgwvk08kk0878fgb9033r': [[1, 2, 2]],
#  'cl74qgwvb089808786iba98mt': [[14, 15, 3], [15, 16, 3]],
#  'cl5l1gjba12y3075jd2luenu7': [[8, 12, 3],
#   [8, 13, 2],
#   [8, 14, 3],
#   [12, 13, 1],
#   [12, 14, 1],
#   [13, 14, 1]],
#  'cl987t0fk1nv7074z0m4aex8k': [],
#  'cl987t0fd1nov074z5675bheb': [[0, 1, 1]],
#  'cl5l1gjbc132b075j6dakfnq6': [],
#  'cl74qgwvs08rs0878gjushgly': [],
#  'cl5l1gjbc1327075jezip2jj0': [],
#  'cl5l1gjb912vj075jdnqm21px': [],
#  'cl74qgwwj09t80878bcgza6yo': [],
#  'cl74qgwvl08m80878dln2an8w': [],
#  'cl5l1gjb912vf075jf773bm2u': [],
#  'cl5l1gjbd135v075j56v94j4m': [],
#  'cl5l1gjbc1323075j1thi1adk': [],
#  'cl74qgwvw08wk08788hui7drx': [],
#  'cl5l1gjb912vb075ja5ivcib4': [],
#  'cl74qgwwg09p00878czg3gchc': [],
#  'cl5l1gjb912v7075j482fdkxe': [],
#  'cl5l1gjb912v3075jgi16gnxn': [],
#  'cl5l1gjb912uz075j7r4chzp2': [],
#  'cl5l1gjb912uv075j5riqgmen': [],
#  'cl5l1gjb912ur075jho327qja': [],
#  'cl5l1gjbc131z075j9c7o1vyq': [],
#  'cl5l1gjb912un075j7ined0kn': [],
#  'cl5l1gjb912uj075j4xk25fg4': [],
#  'cl5l1gjb912uf075jbz9f5qxf': [],
#  'cl74qgwwb09ig0878fmh6avh7': [],
#  'cl5l1gjb812r7075jhslugvv5': [],
#  'cl5l1gjb812r3075j9dc81e7w': [],
#  'cl74qgwwc09jg0878e3t2dxgj': [[0, 1, 2], [1, 2, 2], [2, 6, 2]],
#  'cl74qgwwb09ic0878gbt54ymf': [],
#  'cl987t0fs1o4v074zewqn88kc': [],
#  'cl987t0fs1o4r074z0kwz9dza': [],
#  'cl987t0fs1o4n074zdira14ko': [],
#  'cl5l1gjbf13bv075j7ble0k0n': [],
#  'cl74qgww6099g08781btd71oi': [],
#  'cl987t0fs1o4j074zcqbadkmn': [],
#  'cl987t0fs1o4f074z2j0s6ze3': [],
#  'cl987t0fs1o4b074zhca4gwnf': [],
#  'cl5l1gjbg13gn075jfum95t52': [[0, 1, 2], [1, 2, 2]],
#  'cl987t0fr1o47074z965e2gqa': [],
#  'cl987t0fr1o43074z2ddwh7f8': [],
#  'cl987t0fr1o3z074zcm2sbazm': [],
#  'cl987t0fr1o3v074z49tyfdqn': [],
#  'cl74qgwvs08sc0878egkc0zdm': [],
#  'cl987t0fr1o3r074zhknm24bw': [],
#  'cl987t0fr1o3n074zg8559byd': [],
#  'cl987t0fr1o3j074zc2b7b9a8': [],
#  'cl987t0fr1o3f074z1ttsfvml': [],
#  'cl987t0fr1o3b074z0v3d6ckn': [],
#  'cl5l1gjbh13iv075j9vkm24gt': [[14, 15, 3], [15, 16, 3]],
#  'cl987t0fr1o37074z337m3zv5': [],
#  'cl5l1yjyyd9qk074rfszv2omh': [],
#  'cl987t0fm1ny3074z6b9p7fk5': [[8, 9, 2]],
#  'cl74qgwvo08ok08780bjyepr3': [],
#  'cl5l1yjyyd9qg074rastd7bot': [],
#  'cl987t0fm1nxz074z77ie3dky': [],
#  'cl74qgww0091c0878eksme5tx': [],
#  'cl74qgwvi08hw08780fraa2xe': [[14, 15, 3]],
#  'cl5l1yjyyd9qc074rhyzk4g4c': [],
#  'cl74qgwvj08jo0878854x9fom': [[1, 2, 2]],
#  'cl5l1gjbg13e7075jam5y0qww': [],
#  'cl987t0fc1nnj074zbid3bmq7': [[4, 5, 1], [4, 6, 3], [5, 6, 1]],
#  'cl74qgwwi09rg0878ah9j33vr': [],
#  'cl5l1yjyxd9n0074rhif5dxzj': [],
#  'cl74qgwvp08q8087841bs6xsp': [],
#  'cl5l1gjbg13e3075j5cup0hmd': [],
#  'cl74qgww2094s08780zotheh2': [],
#  'cl74qgww909fk08788dvp85yh': [[0, 9, 3]],
#  'cl987t0fe1nq3074zeco24q6s': [],
#  'cl74qgwvn08no0878g2q2frlw': [],
#  'cl74qgwvl08m40878cvgweo07': [],
#  'cl74qgww50978087852hugch8': [],
#  'cl987t0fj1nuj074z7bsa98jp': [],
#  'cl74qgww2094o0878dn6zan9m': [[13, 14, 2]],
#  'cl987t0fb1nlf074zh8nma3az': [],
#  'cl5l1gjbc131v075j473x4dmh': [],
#  'cl74qgwwe09mc0878bqxp4mxy': [[14, 15, 3]],
#  'cl987t0fa1nkv074zfd8fek50': [],
#  'cl74qgwvh08fk0878hozw50pg': [[14, 15, 3]],
#  'cl5l1gjbd135z075jahvphwjm': [],
#  'cl74qgwwb09i80878h05v3ygq': [],
#  'cl5l1gjbc131r075j94gpeull': [],
#  'cl74qgwwe09m80878a9r185td': [],
#  'cl5l1gjb612lb075j04z1fjzb': [[1, 2, 2]],
#  'cl5l1gjb612lj075jbk4063oy': [[1, 2, 2]],
#  'cl74qgwvw08ws0878ew5tdf01': [],
#  'cl5l1gjb712or075jeejzeyqy': [],
#  'cl74qgwwg09ow087867lq2q9q': [],
#  'cl74qgwvs08s80878hfje36j4': [],
#  'cl74qgwvz08z008782c1rblmt': [],
#  'cl5l1gjb612lf075jacl16w11': [[1, 2, 2]],
#  'cl74qgwvv08vc0878csf86eb9': [],
#  'cl74qgww6099c0878b595as5c': [],
#  'cl74qgww709bs08781xi04xs0': [[5, 14, 2]],
#  'cl5l1gjbh13ir075jcgb8cdq6': [[14, 15, 3], [15, 16, 3]],
#  'cl74qgww5098c0878f36b695g': [[0, 1, 2]],
#  'cl5l1gjba12xz075j0z07d6f5': [[11, 12, 2],
#   [11, 13, 2],
#   [11, 14, 2],
#   [12, 13, 1],
#   [12, 14, 1],
#   [13, 14, 1]],
#  'cl74qgww009180878b65acdmd': [],
#  'cl74qgwvi08hs087818qjd60s': [[14, 15, 3]],
#  'cl5l1gjba12xv075jf841fhqz': [[11, 12, 2],
#   [12, 13, 1],
#   [12, 14, 2],
#   [13, 14, 1]],
#  'cl5l1yjyyd9q8074rcm8b5pe8': [],
#  'cl987t0fe1npz074zcfsih9sz': [],
#  'cl5l1gjbf13br075j6eej78fm': [],
#  'cl74qgwvg08d8087860r2bbwe': [[14, 15, 3]],
#  'cl5l1yjywd9kk074r02wr2axe': [],
#  'cl74qgwv8083g0878fqtwgibm': [[0, 1, 2]],
#  'cl5l1yjyyd9q4074regc34xd6': [],
#  'cl74qgwwi09rc08787w9x9dku': [],
#  'cl74qgwvd08b40878bnlk8mwp': [[15, 16, 3]],
#  'cl5l1yjyyd9q0074r2kyf8nb4': [],
#  'cl74qgwvg08d40878dt7z4flr': [[14, 15, 3]],
#  'cl987t0fk1nun074z91o5hdem': [],
#  'cl74qgwvz08z40878e5jzfylw': [],
#  'cl5l1gjbf13bn075j67om7jar': [],
#  'cl987t0fe1npv074zf956hgxj': [],
#  'cl74qgwvp08q40878dzkz74wn': [],
#  'cl5l1gjbh13gr075j694x76ki': [[0, 1, 2], [2, 3, 2]],
#  'cl5l1yjyyd9pw074rau9l6fa9': [],
#  'cl74qgwva087g08780xnu0zr9': [[13, 14, 3], [14, 15, 3], [15, 16, 3]],
#  'cl74qgww509740878hmimapwq': [],
#  'cl74qgwvb08940878hfkw3uqs': [[15, 16, 3]],
#  'cl74qgww809co08783wvr1rbk': [[0, 1, 2]],
#  'cl5l1gjbg13dz075j76sagywx': [],
#  'cl5l1gjb912ub075j23co6d7o': [],
#  'cl5l1gjb912u7075j2dsjae4o': [],
#  'cl5l1gjb812qz075j351o8pat': [[1, 2, 1]],
#  'cl5l1gjb912u3075je3ck11f7': [],
#  'cl5l1gjb912tz075j4lyl2kn9': [],
#  'cl5l1gjb912tv075jd63e4443': [],
#  'cl5l1gjb912tr075japkh7ika': [],
#  'cl5l1gjb812qv075j34a6295i': [],
#  'cl74qgww809do08785o8ic5ji': [],
#  'cl74qgwvh08fg087813tw31qj': [[14, 15, 3]],
#  'cl5l1gjb912tn075j4s9kctl7': [],
#  'cl74qgww2094k087877aqa24s': [],
#  'cl987t0fr1o33074z8af7hpv1': [],
#  'cl987t0fr1o2v074z7eex635o': [],
#  'cl987t0fr1o2r074zal3ob3df': [],
#  'cl987t0fr1o2n074zfj5ea6cv': [],
#  'cl987t0fr1o2j074z8tvebpda': [],
#  'cl987t0fq1o2f074z2wyi9xdc': [],
#  'cl74qgwvl08m0087834wg17hh': [],
#  'cl74qgwwk09tc08787uhraxp4': [],
#  'cl987t0fq1o2b074z4yqedtem': [],
#  'cl74qgwvw08wo08783qjzgnxs': [],
#  'cl987t0fq1o27074z1d0kd8tn': [],
#  'cl987t0fc1nmv074z1jv5ewvv': [[6, 7, 3], [6, 8, 3], [7, 8, 1]],
#  'cl74qgwwc09jk0878eyef11pj': [[0, 1, 2], [1, 2, 2], [2, 3, 2]],
#  'cl987t0fa1nkr074za3gcd0k0': [],
#  'cl987t0fq1o23074ze6yq0f71': [],
#  'cl987t0fb1nlj074zhhu3647f': [[3, 4, 2]],
#  'cl74qgwwg09os08785bo3g1g3': [],
#  'cl987t0fq1o1z074z2mmcbl1f': [],
#  'cl987t0fq1o1v074z8fmg5t8l': [],
#  'cl74qgwwb09i408782sie9xck': [],
#  'cl987t0fq1o1r074z2uim12k2': [[5, 6, 3]],
#  'cl987t0fq1o1n074z6rrm83fg': [],
#  'cl74qgww609980878e6mk8uzo': [],
#  'cl5l1gjb612l7075jelb91bwi': [[1, 3, 2]],
#  'cl5l1gjbc131n075j44vy8ufk': [],
#  'cl5l1gjb612l3075jcpimepow': [[1, 3, 2]],
#  'cl5l1gjb712ov075j59j5ae2j': [],
#  'cl5l1gjbd1363075j71jw9r0m': [],
#  'cl5l1gjbb131j075jbp314mdm': [],
#  'cl987t0fm1nxv074z0mb0hxc9': [[9, 10, 2]],
#  'cl5l1gjbi13kr075j2xz217e3': [[0, 1, 2], [1, 2, 2], [2, 3, 2]],
#  'cl74qgww009140878ermhe84w': [],
#  'cl987t0fl1nxr074za7lvaj5c': [[8, 9, 2]],
#  'cl74qgwvs08s40878gus3ekiz': [],
#  'cl987t0fl1nxn074zev4edep5': [],
#  'cl5l1gjbh13in075j9rg2f4it': [[15, 16, 3]],
#  'cl5l1yjyyd9ps074r2v89dk4a': [],
#  'cl5l1gjbf13bj075j7he99av1': [],
#  'cl5l1yjyyd9po074rg48t3d84': [],
#  'cl74qgwvi08ho0878gwjt8zu9': [[14, 15, 3]],
#  'cl5l1yjyyd9pk074r26m3hr0p': [],
#  'cl5l1gjbf13bf075j5vz2ex5h': [],
#  'cl5l1gjbh13gv075j7zw45qd8': [[0, 1, 2], [1, 2, 2]],
#  'cl74qgwvw08w808789kd4fd8e': [],
#  'cl987t0fc1nnv074z3mf10yeb': [],
#  'cl74qgwwi09r80878a7eeb5tb': [],
#  'cl987t0fe1npr074zhsts07ze': [],
#  'cl74qgwvp08q00878be7832nh': [],
#  'cl5l1gjbg13dv075jg2327vbc': [],
#  'cl987t0fk1nur074z4z4w3svb': [[3, 4, 2]],
#  'cl74qgww30970087850yzcnyc': [],
#  'cl74qgwvk08lo08780ogt5clm': [],
#  'cl74qgwwb09i00878cm875v71': [],
#  'cl74qgwwe09m40878bpwzao4a': [],
#  'cl74qgwvn08ns08788c316krd': [],
#  'cl74qgww2094g0878f2pu9bbg': [],
#  'cl74qgwvk08ko0878a990dwcx': [],
#  'cl987t0fk1nvv074zc1cch4tp': [],
#  'cl987t0fa1nkn074za072gxn4': [],
#  'cl74qgwvh08fc0878d1k614yh': [[14, 15, 3]],
#  'cl5l1gjbb131f075j3c7n1gvk': [],
#  ...}

# %%
out_rel = {"train": image_rel, "rel_categories": rel_cat}

# %%
with open("oic_rel.json", "w") as file:
    json.dump(out_rel, file)
    file.close()
