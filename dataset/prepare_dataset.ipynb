# %%
import json

# %%
def import_file(path):
    with open(path, "r") as file:
        c = json.load(file)
        file.close()
        return c
    
def create_relations(annotations):
    """
    For every image, creates a list of triples in the form of (s, o, p)
    where s and o are the indexes of the annotations within the image and p is the index of the relation_category
    """

def get_bbox_relation(a, b):
    """
    Simple heuristic to return a rel_cat id to two bounding boxes
    """
    a_xyxy = xywh_to_xyxy(a)
    b_xyxy = xywh_to_xyxy(b)
    if box_similarity(a_xyxy, b_xyxy) > 0.6:
        return 0
    elif box_similarity(a_xyxy, b_xyxy) > 0.3:
        if a[1] > b[1]: # When a is below b
            return 1
        else:
            return 2
    return None
    
def xywh_to_xyxy(a):
    return (a[0] + a[2], a[0], a[1] + a[3], a[1])

def box_similarity(a, b):
    """
    Returns fraction of overlap with b to own box. 1 if perfect overlap, 0 if no overlap
    a == b == [xmax, xmin, ymax, ymin]
    """
    a_a = (a[0] - a[1]) * (a[2] - a[3])
    a_b = (b[0] - b[1]) * (b[2] - b[3])
    overlap = max(min(a[0], b[0]) - max(a[1], b[1]), 0) * \
              max(min(a[2], b[2]) - max(a[3], b[3]), 0)

    if a_a > a_b:
        return overlap / a_a
    else:
        return overlap / a_b

rel_cat = ["on", "below", "above"]

# %%
train = import_file("train.json")

# %%
img_id2id = dict()
for i, img in enumerate(train["images"]):
    idx = img["id"]
    img_id2id[idx] = i
    train["images"][i]["id"] = i

# %%
new_annotations = []
for i, ann in enumerate(train["annotations"]):
    idx = ann["image_id"]
    ann["image_id"] = img_id2id[idx]
    new_annotations.append(ann)
train["annotations"] = new_annotations

# %%
for ann in train["annotations"]:
    ann["area"] = ann["bbox"][2] * ann["bbox"][3]

# %%
image2ann = dict()
for a in train["annotations"]:
    image_id = a["image_id"]
    if image_id in image2ann.keys():
        image2ann[image_id].append(a)
    else:
        image2ann[image_id] = [a]

# %%
# For every image, examine their annotiosw
image_rel = dict()
for img, ann_list in image2ann.items():
    triples = []
    for i, a in enumerate(ann_list):
        for j, b in enumerate(ann_list):
            if i >= j:
                continue
            rel = get_bbox_relation(a["bbox"], b["bbox"])
            if rel:
                triples.append([i, j, rel])
    image_rel[img] = triples

# %%
train["images"][0]
# Out:
# {'license': 1,
#  'file_name': 'Video 1 ezgif-frame-001 (1).jpg',
#  'height': 1920,
#  'width': 1080,
#  'date_captured': '2022-07-14 12:59:58',
#  'id': 0,
#  'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F63c21fac-d49f-7072-1767-c8e9c57c2d51-Video%201%20ezgif-frame-001%20(1).jpg?Expires=1673986338674&KeyName=labelbox-assets-key-3&Signature=g-O_Or88jf5eYGrELX5Do-9sAJ0'}

# %%
image_rel
# Out:
# {1068: [],
#  986: [],
#  1058: [],
#  1003: [],
#  757: [],
#  597: [[4, 5, 1]],
#  815: [],
#  146: [[3, 10, 2], [6, 7, 2], [7, 8, 2]],
#  550: [],
#  886: [[0, 16, 2]],
#  198: [],
#  621: [],
#  255: [],
#  283: [[3, 4, 1], [4, 5, 1], [5, 6, 1]],
#  838: [[4, 9, 1]],
#  985: [],
#  549: [],
#  1064: [],
#  598: [[1, 2, 1]],
#  1057: [],
#  254: [],
#  997: [],
#  756: [],
#  145: [[0, 3, 1], [6, 7, 2], [7, 8, 2], [8, 9, 2]],
#  1069: [],
#  660: [],
#  0: [[4, 13, 1],
#   [4, 27, 1],
#   [7, 10, 1],
#   [10, 26, 2],
#   [12, 30, 2],
#   [13, 19, 2],
#   [19, 27, 1]],
#  894: [[6, 7, 2]],
#  699: [],
#  916: [],
#  731: [],
#  1010: [[1, 3, 2]],
#  41: [],
#  966: [[0, 1, 2], [0, 11, 1]],
#  698: [],
#  825: [[1, 11, 1], [9, 12, 2]],
#  28: [],
#  893: [[14, 15, 2]],
#  830: [[0, 7, 2]],
#  1025: [[2, 3, 1]],
#  4: [[8, 30, 1],
#   [11, 31, 1],
#   [13, 14, 2],
#   [13, 25, 2],
#   [14, 16, 1],
#   [16, 25, 2]],
#  684: [],
#  915: [],
#  732: [[0, 11, 2]],
#  892: [[14, 15, 2]],
#  1089: [],
#  777: [[0, 1, 1]],
#  235: [],
#  798: [],
#  799: [],
#  249: [],
#  703: [],
#  842: [[3, 12, 2]],
#  234: [],
#  845: [[5, 13, 1]],
#  882: [[8, 9, 1], [9, 10, 1]],
#  807: [[1, 7, 1]],
#  286: [[5, 6, 2], [6, 7, 2]],
#  342: [],
#  702: [],
#  233: [],
#  797: [[13, 14, 2]],
#  884: [[6, 7, 1]],
#  697: [],
#  348: [],
#  507: [[2, 3, 2]],
#  644: [],
#  563: [[9, 10, 1]],
#  650: [],
#  292: [[5, 6, 1], [6, 12, 1], [7, 12, 2]],
#  833: [[5, 8, 1]],
#  506: [[13, 14, 2], [14, 15, 2]],
#  410: [[15, 16, 2]],
#  280: [[0, 1, 2], [2, 3, 2]],
#  643: [],
#  651: [],
#  279: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  318: [],
#  439: [[6, 7, 1], [8, 14, 1]],
#  505: [[12, 14, 2]],
#  349: [],
#  529: [[3, 4, 2]],
#  438: [[13, 14, 1]],
#  595: [],
#  555: [[0, 1, 1]],
#  604: [],
#  302: [[15, 16, 2]],
#  693: [],
#  328: [[10, 11, 1]],
#  619: [],
#  321: [[0, 1, 2], [0, 12, 1]],
#  528: [[14, 15, 2]],
#  661: [],
#  603: [],
#  413: [[3, 4, 2], [4, 5, 2]],
#  622: [],
#  488: [[2, 3, 2]],
#  938: [],
#  1014: [[0, 1, 2], [0, 2, 2]],
#  956: [[1, 10, 1]],
#  937: [],
#  487: [[14, 15, 2]],
#  1056: [[8, 9, 2]],
#  914: [],
#  967: [],
#  486: [[14, 15, 2]],
#  1023: [],
#  566: [],
#  855: [],
#  470: [[0, 1, 2]],
#  115: [[3, 5, 1], [3, 6, 1], [4, 6, 1]],
#  1004: [],
#  591: [],
#  878: [[8, 9, 1], [10, 16, 1]],
#  984: [],
#  469: [[14, 15, 2]],
#  624: [],
#  816: [],
#  854: [],
#  548: [],
#  114: [[12, 14, 1], [13, 15, 1]],
#  755: [],
#  870: [],
#  694: [],
#  659: [],
#  468: [[14, 15, 2]],
#  1027: [],
#  113: [],
#  1087: [],
#  879: [[0, 3, 1], [1, 2, 1], [1, 3, 2]],
#  565: [],
#  996: [],
#  983: [],
#  411: [[11, 13, 1]],
#  199: [],
#  452: [[0, 16, 1], [15, 16, 2]],
#  203: [],
#  451: [[14, 15, 2], [15, 16, 2]],
#  257: [],
#  282: [[5, 6, 2], [5, 7, 1]],
#  186: [],
#  258: [],
#  185: [],
#  144: [[0, 2, 1], [4, 5, 2], [5, 6, 2]],
#  346: [],
#  450: [[14, 15, 2], [15, 16, 2]],
#  143: [[0, 2, 1], [4, 5, 2], [5, 6, 2]],
#  344: [],
#  184: [],
#  683: [],
#  74: [[9, 10, 2], [10, 12, 2]],
#  737: [],
#  823: [[4, 13, 1]],
#  883: [[1, 2, 1], [2, 3, 1]],
#  73: [[11, 12, 2], [12, 14, 2]],
#  701: [],
#  796: [],
#  869: [],
#  682: [],
#  834: [[1, 6, 1]],
#  1186: [[7, 8, 2]],
#  1132: [],
#  50: [],
#  1131: [],
#  250: [],
#  1130: [],
#  232: [],
#  1185: [[5, 6, 2]],
#  1129: [],
#  343: [],
#  1128: [],
#  49: [],
#  3: [[0, 6, 2], [6, 16, 1], [11, 31, 1], [16, 25, 2]],
#  27: [],
#  1184: [[4, 5, 2], [5, 6, 2]],
#  1127: [],
#  231: [],
#  48: [],
#  1126: [],
#  724: [],
#  301: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  768: [[7, 8, 1]],
#  527: [[13, 14, 1]],
#  642: [],
#  810: [[7, 13, 1]],
#  885: [[0, 1, 2], [1, 2, 2]],
#  329: [],
#  840: [],
#  913: [],
#  723: [],
#  278: [[13, 14, 2], [15, 16, 2]],
#  350: [],
#  1102: [],
#  1055: [[8, 9, 2]],
#  1101: [],
#  142: [[0, 2, 1], [5, 6, 2], [6, 7, 2]],
#  200: [],
#  754: [],
#  1070: [],
#  183: [[3, 4, 2]],
#  1100: [],
#  141: [[0, 2, 1], [5, 6, 2], [6, 7, 2]],
#  1054: [[8, 9, 2]],
#  592: [],
#  564: [[13, 14, 2]],
#  284: [[0, 1, 1], [2, 3, 1]],
#  936: [],
#  853: [],
#  1156: [],
#  891: [[14, 15, 2]],
#  685: [],
#  1090: [[9, 10, 1]],
#  982: [],
#  957: [[3, 12, 1]],
#  681: [],
#  1005: [],
#  935: [],
#  852: [],
#  730: [],
#  547: [[13, 14, 2]],
#  832: [[1, 13, 2]],
#  700: [],
#  599: [],
#  230: [],
#  1009: [[5, 6, 2]],
#  968: [[1, 2, 1]],
#  912: [],
#  229: [],
#  319: [],
#  251: [],
#  29: [],
#  800: [],
#  2: [[11, 31, 1], [14, 16, 1], [16, 25, 2]],
#  641: [],
#  504: [[14, 15, 2]],
#  30: [],
#  795: [[13, 14, 2]],
#  652: [],
#  26: [],
#  503: [[14, 15, 2]],
#  300: [[13, 14, 2], [15, 16, 2]],
#  330: [],
#  769: [],
#  320: [[8, 9, 2], [9, 10, 2]],
#  485: [[14, 15, 2]],
#  351: [],
#  440: [[0, 1, 2], [2, 3, 1]],
#  277: [[14, 15, 2], [15, 16, 2]],
#  722: [],
#  317: [],
#  331: [],
#  140: [[0, 3, 2], [0, 4, 2], [3, 4, 2], [5, 6, 2], [6, 8, 2]],
#  526: [[13, 14, 1]],
#  449: [[14, 15, 2], [15, 16, 2]],
#  112: [],
#  556: [[1, 2, 1]],
#  467: [[14, 15, 2]],
#  201: [],
#  111: [],
#  139: [[0, 3, 2], [0, 4, 2], [3, 4, 2], [5, 6, 2], [6, 8, 2]],
#  448: [[12, 16, 2], [14, 16, 1]],
#  466: [[14, 15, 2]],
#  546: [],
#  182: [],
#  911: [[13, 14, 2]],
#  259: [],
#  981: [],
#  880: [[0, 1, 1], [1, 2, 1]],
#  1071: [[3, 4, 2], [7, 8, 1]],
#  1053: [[8, 9, 2]],
#  851: [],
#  934: [],
#  181: [],
#  1088: [],
#  425: [[12, 13, 2], [13, 14, 2]],
#  72: [[0, 2, 2], [5, 6, 2], [6, 8, 2]],
#  430: [[3, 4, 1], [5, 6, 1]],
#  1183: [],
#  1125: [[0, 3, 2]],
#  429: [[4, 6, 2], [5, 7, 2]],
#  47: [],
#  753: [],
#  1124: [[0, 3, 2]],
#  431: [[0, 1, 1]],
#  71: [],
#  1123: [[1, 2, 2]],
#  817: [],
#  1182: [[7, 8, 2]],
#  680: [],
#  46: [],
#  70: [],
#  1122: [[1, 2, 2]],
#  868: [],
#  424: [[13, 14, 2], [15, 16, 2]],
#  228: [],
#  640: [],
#  285: [[4, 5, 2], [5, 6, 2], [6, 7, 2]],
#  696: [],
#  227: [],
#  226: [],
#  299: [[15, 16, 2]],
#  412: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  794: [[13, 14, 2]],
#  332: [],
#  844: [[0, 9, 2]],
#  1099: [],
#  1098: [[7, 8, 1]],
#  721: [],
#  25: [],
#  31: [],
#  1097: [],
#  525: [[14, 15, 2]],
#  969: [],
#  910: [[13, 14, 2]],
#  352: [],
#  1052: [],
#  958: [[3, 11, 1]],
#  276: [[13, 14, 2], [15, 16, 2]],
#  933: [],
#  1072: [],
#  1: [[7, 11, 1], [7, 15, 1], [12, 13, 1], [12, 30, 1], [15, 24, 2]],
#  980: [],
#  752: [],
#  837: [[1, 9, 2]],
#  979: [],
#  890: [[14, 15, 2]],
#  545: [],
#  620: [],
#  138: [[0, 3, 2], [0, 4, 2], [3, 4, 2], [5, 6, 2], [6, 8, 2]],
#  733: [],
#  584: [[5, 6, 2]],
#  602: [[5, 6, 1]],
#  180: [[3, 4, 2]],
#  679: [],
#  850: [],
#  889: [[14, 15, 2]],
#  137: [[0, 2, 2], [0, 3, 2], [2, 3, 2], [4, 5, 2], [5, 7, 2]],
#  736: [[13, 14, 1]],
#  583: [],
#  686: [],
#  202: [],
#  423: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  502: [[14, 15, 2]],
#  907: [[11, 12, 2]],
#  970: [[6, 7, 1]],
#  225: [],
#  1008: [[0, 1, 2], [0, 8, 1]],
#  793: [],
#  801: [],
#  224: [],
#  971: [[1, 11, 2]],
#  223: [],
#  906: [],
#  252: [],
#  484: [[14, 15, 2]],
#  298: [[13, 14, 2], [15, 16, 2]],
#  909: [[13, 14, 2]],
#  639: [],
#  333: [],
#  770: [[0, 1, 1]],
#  720: [],
#  483: [[14, 15, 2]],
#  24: [],
#  653: [],
#  738: [],
#  110: [],
#  826: [],
#  109: [],
#  465: [[14, 15, 2]],
#  108: [],
#  831: [[1, 6, 1]],
#  1006: [],
#  353: [],
#  524: [[11, 12, 2]],
#  594: [[13, 14, 2]],
#  1051: [],
#  1181: [[3, 13, 2], [4, 5, 2]],
#  69: [],
#  136: [[0, 3, 2], [2, 3, 2], [4, 5, 2], [4, 6, 2], [5, 7, 2]],
#  849: [],
#  447: [[13, 15, 1], [14, 16, 2]],
#  978: [],
#  932: [],
#  881: [[0, 1, 1], [1, 2, 1]],
#  68: [],
#  275: [[13, 14, 2], [15, 16, 2]],
#  557: [],
#  1180: [[5, 6, 2]],
#  135: [[0, 2, 2], [3, 4, 2], [4, 6, 2]],
#  1073: [],
#  1050: [],
#  1013: [[0, 11, 1], [1, 11, 1]],
#  751: [],
#  322: [[6, 7, 2], [7, 8, 2], [8, 9, 2]],
#  627: [],
#  45: [],
#  179: [],
#  187: [],
#  44: [],
#  818: [],
#  582: [],
#  178: [],
#  750: [],
#  658: [],
#  432: [[0, 1, 1], [1, 2, 1]],
#  222: [],
#  544: [[13, 14, 2]],
#  600: [],
#  221: [],
#  220: [],
#  678: [],
#  219: [],
#  1096: [],
#  218: [],
#  217: [],
#  216: [],
#  215: [],
#  214: [],
#  213: [],
#  212: [],
#  422: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  1095: [],
#  211: [],
#  908: [[13, 14, 2]],
#  972: [],
#  995: [],
#  846: [[8, 10, 1]],
#  638: [],
#  1121: [[2, 3, 2], [8, 9, 1]],
#  1026: [],
#  829: [[0, 9, 2]],
#  1120: [[2, 3, 2]],
#  297: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  334: [],
#  792: [],
#  719: [],
#  32: [],
#  23: [],
#  729: [],
#  523: [[14, 15, 2]],
#  354: [],
#  888: [[14, 15, 2]],
#  274: [[13, 14, 2], [15, 16, 2]],
#  1049: [],
#  887: [[14, 15, 2]],
#  501: [[12, 13, 2], [13, 14, 2]],
#  977: [],
#  848: [],
#  931: [],
#  959: [[3, 12, 1]],
#  500: [[14, 15, 2]],
#  433: [[0, 6, 1]],
#  749: [],
#  976: [],
#  421: [[13, 14, 2], [15, 16, 2]],
#  543: [[13, 14, 2]],
#  585: [],
#  626: [],
#  677: [],
#  177: [],
#  581: [],
#  188: [],
#  542: [[13, 14, 2]],
#  508: [[3, 4, 2]],
#  210: [],
#  367: [],
#  441: [[4, 6, 2], [5, 6, 1]],
#  408: [[5, 6, 1], [7, 8, 1]],
#  209: [],
#  828: [[0, 9, 2]],
#  366: [],
#  208: [],
#  365: [],
#  207: [],
#  409: [[0, 15, 1]],
#  364: [],
#  316: [[0, 1, 2], [0, 13, 2], [1, 2, 2]],
#  791: [[13, 14, 2]],
#  446: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  637: [],
#  134: [[0, 2, 2], [3, 4, 2], [3, 5, 2], [4, 6, 2]],
#  253: [],
#  464: [[14, 15, 2]],
#  482: [[14, 15, 2]],
#  133: [[0, 2, 2], [3, 4, 2], [3, 5, 2], [4, 6, 2]],
#  802: [],
#  445: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  463: [[14, 15, 2]],
#  132: [[0, 2, 2], [3, 4, 2], [3, 5, 2], [4, 6, 2]],
#  481: [[14, 15, 2]],
#  790: [[13, 14, 2]],
#  954: [[8, 13, 1]],
#  1015: [[0, 2, 1]],
#  296: [[13, 14, 2], [15, 16, 2]],
#  809: [[0, 9, 2]],
#  335: [],
#  841: [],
#  1022: [],
#  718: [],
#  827: [[1, 10, 2]],
#  728: [],
#  771: [[0, 1, 1]],
#  767: [],
#  953: [[0, 9, 2]],
#  336: [],
#  522: [[14, 15, 2]],
#  67: [],
#  355: [],
#  1179: [[7, 8, 2], [8, 9, 2]],
#  107: [],
#  22: [],
#  66: [],
#  106: [],
#  273: [],
#  1178: [[6, 7, 2], [8, 9, 2]],
#  356: [],
#  65: [],
#  521: [[14, 15, 2]],
#  105: [],
#  1074: [],
#  687: [],
#  1007: [[4, 5, 1]],
#  676: [],
#  1048: [],
#  975: [],
#  748: [],
#  819: [],
#  420: [[13, 14, 2], [15, 16, 2]],
#  43: [],
#  847: [[0, 9, 2]],
#  930: [[0, 8, 2]],
#  42: [],
#  580: [],
#  323: [[0, 1, 2], [0, 3, 1], [1, 2, 2]],
#  315: [[13, 14, 2], [14, 15, 2]],
#  176: [],
#  1119: [[2, 3, 1]],
#  1094: [],
#  437: [[0, 1, 2]],
#  1118: [[0, 3, 2]],
#  601: [],
#  175: [],
#  1093: [],
#  541: [[13, 14, 2]],
#  1016: [],
#  206: [],
#  905: [],
#  952: [[0, 9, 2]],
#  205: [],
#  789: [[13, 14, 2]],
#  811: [],
#  636: [],
#  295: [[13, 14, 2], [15, 16, 2]],
#  654: [],
#  717: [],
#  727: [],
#  872: [],
#  337: [],
#  415: [[13, 16, 2], [15, 16, 1]],
#  436: [[8, 9, 1], [9, 10, 1]],
#  403: [[13, 14, 1]],
#  33: [],
#  558: [[1, 2, 1]],
#  1075: [],
#  1047: [],
#  623: [],
#  974: [],
#  21: [],
#  272: [],
#  357: [],
#  520: [[14, 15, 2]],
#  836: [[0, 9, 2]],
#  499: [[14, 15, 2]],
#  929: [[0, 8, 2]],
#  960: [],
#  586: [],
#  747: [],
#  579: [],
#  498: [[14, 15, 2]],
#  314: [[12, 13, 2], [13, 14, 2], [14, 15, 2]],
#  675: [],
#  174: [],
#  480: [[14, 15, 2]],
#  189: [],
#  434: [[0, 1, 1], [1, 2, 1]],
#  173: [],
#  540: [[13, 14, 2]],
#  414: [[15, 16, 2]],
#  419: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  635: [],
#  131: [[0, 3, 2], [1, 2, 2], [1, 4, 2], [2, 6, 2]],
#  294: [[14, 15, 2], [15, 16, 2]],
#  204: [],
#  130: [[0, 2, 2], [3, 4, 2], [3, 5, 2], [4, 6, 2]],
#  338: [],
#  129: [[0, 2, 2], [3, 4, 2], [3, 5, 2], [4, 6, 2]],
#  824: [[0, 4, 2]],
#  128: [[0, 2, 2], [3, 5, 2], [3, 6, 2]],
#  695: [],
#  634: [],
#  716: [],
#  64: [],
#  462: [[14, 15, 2]],
#  104: [],
#  951: [[0, 9, 2]],
#  788: [[13, 14, 2]],
#  63: [],
#  803: [],
#  103: [],
#  772: [],
#  1017: [[3, 4, 1]],
#  461: [[15, 16, 2]],
#  1046: [],
#  444: [[12, 13, 2], [13, 15, 2], [15, 16, 2]],
#  726: [],
#  404: [[2, 3, 2]],
#  20: [],
#  1076: [],
#  19: [],
#  34: [],
#  402: [[13, 14, 1]],
#  1045: [],
#  18: [],
#  662: [],
#  1117: [[0, 3, 2]],
#  692: [],
#  1177: [],
#  994: [],
#  616: [],
#  1116: [],
#  1176: [],
#  734: [],
#  519: [[14, 15, 2]],
#  615: [],
#  1115: [],
#  973: [],
#  428: [[7, 8, 2], [8, 9, 2], [9, 10, 2]],
#  746: [[13, 14, 1]],
#  271: [],
#  358: [],
#  427: [[14, 15, 2], [15, 16, 2]],
#  418: [[13, 14, 2], [15, 16, 2]],
#  674: [],
#  928: [],
#  688: [],
#  1024: [],
#  578: [[13, 14, 2]],
#  673: [],
#  1012: [[4, 6, 2]],
#  904: [[13, 14, 2]],
#  172: [],
#  256: [],
#  903: [[13, 14, 2]],
#  171: [],
#  313: [[12, 13, 2], [13, 14, 2], [14, 15, 2]],
#  843: [[0, 9, 2]],
#  655: [],
#  324: [[0, 1, 1], [1, 2, 1], [2, 3, 1]],
#  787: [],
#  633: [],
#  312: [[12, 13, 2], [13, 14, 2], [14, 15, 2]],
#  1091: [[4, 5, 1]],
#  715: [],
#  725: [],
#  293: [[11, 12, 2], [12, 13, 2], [13, 14, 2]],
#  950: [],
#  17: [],
#  339: [],
#  16: [],
#  401: [],
#  539: [[13, 14, 2]],
#  714: [],
#  15: [],
#  270: [],
#  359: [],
#  663: [],
#  614: [],
#  479: [[14, 15, 2]],
#  1044: [],
#  577: [],
#  1077: [],
#  478: [[14, 15, 2]],
#  426: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  587: [],
#  435: [[0, 1, 1]],
#  820: [],
#  497: [[14, 15, 2]],
#  745: [[13, 14, 1]],
#  867: [],
#  559: [],
#  460: [[14, 15, 2], [15, 16, 2]],
#  518: [[14, 15, 2]],
#  496: [[14, 15, 2]],
#  873: [[0, 3, 1], [2, 3, 2], [2, 4, 1]],
#  127: [[0, 3, 2], [2, 3, 2], [5, 7, 2]],
#  927: [],
#  170: [],
#  190: [],
#  102: [],
#  735: [],
#  126: [[3, 4, 2]],
#  169: [],
#  961: [],
#  345: [],
#  168: [],
#  125: [[3, 4, 2], [7, 8, 2]],
#  101: [],
#  672: [],
#  167: [],
#  632: [],
#  124: [[5, 6, 2], [10, 11, 2], [10, 12, 2]],
#  926: [],
#  100: [],
#  62: [],
#  786: [],
#  61: [],
#  538: [],
#  311: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  949: [],
#  443: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  400: [],
#  1114: [],
#  1018: [[3, 4, 1], [6, 7, 1]],
#  405: [[0, 1, 2], [2, 3, 2]],
#  1021: [],
#  1113: [[5, 6, 1]],
#  713: [],
#  399: [],
#  948: [],
#  778: [[7, 8, 2]],
#  1175: [[1, 2, 2], [2, 3, 2], [5, 8, 2]],
#  1043: [],
#  360: [],
#  269: [],
#  1078: [],
#  1174: [[2, 3, 2], [5, 8, 2]],
#  766: [[13, 14, 2]],
#  1042: [],
#  35: [],
#  14: [],
#  13: [],
#  613: [],
#  417: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  593: [],
#  835: [[0, 9, 2]],
#  902: [[13, 14, 2]],
#  866: [],
#  744: [[13, 14, 1]],
#  901: [],
#  517: [[14, 15, 2]],
#  925: [],
#  871: [],
#  576: [],
#  804: [[0, 1, 1], [5, 14, 1]],
#  166: [],
#  165: [],
#  191: [],
#  164: [],
#  785: [[13, 14, 2]],
#  689: [],
#  551: [],
#  163: [],
#  671: [],
#  537: [[14, 15, 2]],
#  162: [],
#  161: [],
#  260: [],
#  773: [],
#  287: [[4, 5, 2], [5, 6, 2], [6, 7, 2]],
#  288: [[0, 1, 1], [1, 2, 1]],
#  656: [],
#  325: [[0, 1, 1], [1, 2, 1], [2, 3, 1]],
#  712: [],
#  808: [[0, 9, 2]],
#  247: [],
#  631: [],
#  310: [[14, 15, 2], [15, 16, 2]],
#  398: [],
#  812: [[0, 1, 1]],
#  495: [[13, 14, 2], [14, 15, 2]],
#  397: [],
#  765: [[13, 14, 2]],
#  396: [],
#  361: [],
#  12: [],
#  743: [[13, 14, 1]],
#  268: [],
#  477: [[14, 15, 2]],
#  36: [],
#  821: [],
#  11: [],
#  1079: [],
#  1041: [],
#  947: [],
#  10: [[1, 2, 1]],
#  612: [],
#  476: [[14, 15, 2]],
#  664: [],
#  362: [],
#  416: [[14, 15, 2], [15, 16, 2]],
#  459: [[15, 16, 2]],
#  123: [[11, 12, 2], [11, 13, 2], [11, 14, 2]],
#  516: [[14, 15, 2]],
#  560: [[1, 2, 1]],
#  458: [[14, 15, 2], [15, 16, 2]],
#  122: [[8, 12, 2], [8, 13, 1], [8, 14, 2]],
#  1086: [],
#  1029: [],
#  160: [],
#  625: [],
#  159: [],
#  99: [],
#  962: [],
#  575: [],
#  98: [],
#  192: [],
#  158: [],
#  670: [],
#  97: [],
#  924: [],
#  96: [],
#  95: [],
#  94: [],
#  93: [],
#  92: [],
#  157: [],
#  91: [],
#  90: [],
#  89: [],
#  865: [],
#  60: [],
#  59: [],
#  874: [[0, 1, 1], [1, 2, 1], [2, 6, 1]],
#  864: [],
#  1173: [],
#  1172: [],
#  1171: [],
#  246: [],
#  784: [],
#  1170: [],
#  1169: [],
#  1168: [],
#  289: [[0, 1, 1], [1, 2, 1]],
#  1167: [],
#  1166: [],
#  1165: [],
#  1164: [],
#  630: [],
#  1163: [],
#  1162: [],
#  1161: [],
#  1160: [],
#  1159: [],
#  309: [[14, 15, 2], [15, 16, 2]],
#  1158: [],
#  395: [],
#  1112: [[8, 9, 1]],
#  596: [],
#  394: [],
#  1111: [],
#  711: [],
#  536: [[14, 15, 2]],
#  393: [],
#  552: [[1, 2, 1]],
#  267: [],
#  1019: [[4, 6, 2]],
#  946: [],
#  363: [],
#  611: [],
#  266: [],
#  742: [],
#  839: [[0, 9, 2]],
#  1040: [],
#  588: [],
#  574: [],
#  764: [],
#  1080: [],
#  741: [[13, 14, 1]],
#  998: [],
#  156: [],
#  900: [[14, 15, 2]],
#  993: [],
#  515: [[14, 15, 2]],
#  193: [],
#  863: [],
#  155: [],
#  899: [],
#  9: [[1, 2, 1]],
#  8: [[1, 2, 1]],
#  669: [],
#  37: [],
#  923: [],
#  629: [],
#  690: [],
#  7: [[1, 2, 1]],
#  657: [],
#  783: [],
#  805: [[5, 14, 1]],
#  308: [[14, 15, 2], [15, 16, 2]],
#  774: [[0, 1, 1]],
#  121: [[11, 12, 1], [11, 13, 1], [11, 14, 1]],
#  710: [],
#  535: [[14, 15, 2]],
#  120: [[11, 12, 1], [12, 14, 1]],
#  392: [],
#  1039: [],
#  245: [],
#  494: [[14, 15, 2]],
#  341: [],
#  406: [[0, 1, 1]],
#  391: [],
#  945: [],
#  475: [[15, 16, 2]],
#  390: [],
#  493: [[14, 15, 2]],
#  1081: [],
#  691: [],
#  244: [],
#  1038: [],
#  610: [],
#  290: [[0, 1, 1], [2, 3, 1]],
#  389: [],
#  442: [[13, 14, 2], [14, 15, 2], [15, 16, 2]],
#  763: [],
#  457: [[15, 16, 2]],
#  813: [[0, 1, 1]],
#  265: [],
#  88: [],
#  87: [],
#  58: [],
#  86: [],
#  85: [],
#  84: [],
#  83: [],
#  57: [],
#  822: [],
#  514: [[14, 15, 2]],
#  82: [],
#  740: [],
#  1157: [],
#  1155: [],
#  1154: [],
#  1153: [],
#  1152: [],
#  1151: [],
#  573: [],
#  963: [],
#  1150: [],
#  668: [],
#  1149: [],
#  1011: [[6, 7, 2], [6, 8, 2]],
#  875: [[0, 1, 1], [1, 2, 1], [2, 3, 1]],
#  992: [],
#  1148: [],
#  999: [[3, 4, 1]],
#  922: [],
#  1147: [],
#  1146: [],
#  862: [],
#  1145: [[5, 6, 2]],
#  1144: [],
#  782: [],
#  6: [[1, 3, 1]],
#  154: [],
#  5: [[1, 3, 1]],
#  38: [],
#  194: [],
#  153: [],
#  1110: [[9, 10, 1]],
#  326: [[0, 1, 1], [1, 2, 1], [2, 3, 1]],
#  709: [],
#  1109: [[8, 9, 1]],
#  628: [],
#  1108: [],
#  307: [[15, 16, 2]],
#  388: [],
#  243: [],
#  387: [],
#  534: [[14, 15, 2]],
#  386: [],
#  242: [],
#  291: [[0, 1, 1], [1, 2, 1]],
#  665: [],
#  1020: [],
#  944: [],
#  1037: [],
#  609: [],
#  264: [],
#  1082: [[3, 4, 1]],
#  762: [],
#  572: [],
#  861: [],
#  898: [],
#  589: [],
#  739: [],
#  561: [],
#  1092: [],
#  991: [],
#  513: [[14, 15, 2]],
#  152: [],
#  ...}

# %%
train_img = list(image_rel.keys())[:1000]
val_img = list(image_rel.keys())[1001:]

# %%
rel_train = dict()
rel_val = dict()
for i in train_img:
    rel_train[i] = image_rel[i]
    
for i in val_img:
    rel_val[i] = image_rel[i]

# %%
out_rel = {"train": rel_train, "val": rel_val, "rel_categories": rel_cat}

# %%
with open("oic_rel.json", "w") as file:
    json.dump(out_rel, file)
    file.close()

# %%
val_img = set(val_img)
train_img = set(train_img)
img_train = []
img_val = []
for i in train["images"]:
    if i["id"] in val_img:
        img_val.append(i)
    elif i["id"] in train_img: # we cannot be sure only with complement
        img_train.append(i)

# %%
ann_train = []
ann_val = []
for a in train["annotations"]:
    if a["image_id"] in val_img:
        ann_val.append(a)
    elif a["image_id"] in train_img: # we cannot be sure only with complement
        ann_train.append(a)

# %%
print(len(img_val))
print(len(img_train))
# Out:
# 186
# 1000

# %%
print(len(ann_val))
print(len(ann_train))
print(len(train["annotations"]))
# Out:
# 2375
# 12585
# 14973

# %%
image_dict_train = {"info": train["info"], "licenses": train["licenses"], "images": img_train, "annotations": ann_train, "categories": train["categories"]}
image_dict_val = {"info": train["info"], "licenses": train["licenses"], "images": img_val, "annotations": ann_val, "categories": train["categories"]}

# %%
with open("oic_train.json", "w") as file:
    json.dump(image_dict_train, file)
    file.close()

# %%
with open("oic_val.json", "w") as file:
    json.dump(image_dict_val, file)
    file.close()

# %%
train["images"]
# Out:
# [{'license': 1,
#   'file_name': 'Video 1 ezgif-frame-001 (1).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 0,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F63c21fac-d49f-7072-1767-c8e9c57c2d51-Video%201%20ezgif-frame-001%20(1).jpg?Expires=1673986338674&KeyName=labelbox-assets-key-3&Signature=g-O_Or88jf5eYGrELX5Do-9sAJ0'},
#  {'license': 1,
#   'file_name': 'Video 1 ezgif-frame-001 (87).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 1,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fad77ff31-d64f-dac3-d5f3-a637fc77a07d-Video%201%20ezgif-frame-001%20(87).jpg?Expires=1673986338674&KeyName=labelbox-assets-key-3&Signature=zM6kxZej8OXssGbFtUu5OAbSLes'},
#  {'license': 1,
#   'file_name': 'Video 1 ezgif-frame-001 (88).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 2,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F1c859f24-0065-1971-3e7f-0d1dd7798259-Video%201%20ezgif-frame-001%20(88).jpg?Expires=1673986338674&KeyName=labelbox-assets-key-3&Signature=96Gyj7qr9fiVk2bVKxiG0rsLDRU'},
#  {'license': 1,
#   'file_name': 'Video 1 ezgif-frame-001 (89).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 3,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fd7721592-dfa5-75cc-84e6-030dde5cacce-Video%201%20ezgif-frame-001%20(89).jpg?Expires=1673986338674&KeyName=labelbox-assets-key-3&Signature=JU3_RU-l27e_iTwIttGF_gafKGE'},
#  {'license': 1,
#   'file_name': 'Video 1 ezgif-frame-001 (90).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 4,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F3f47f3d3-4031-7366-1c72-e9e2b782ac43-Video%201%20ezgif-frame-001%20(90).jpg?Expires=1673986338673&KeyName=labelbox-assets-key-3&Signature=vcryafxruH6kx3NQtLqdqBys_Ys'},
#  {'license': 1,
#   'file_name': 'Video 2 ezgif-frame-001 (58).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 5,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F2d4ea62d-d5fe-f452-ef6e-cbffd390cba8-Video%202%20ezgif-frame-001%20(58).jpg?Expires=1673986338673&KeyName=labelbox-assets-key-3&Signature=H9rCU3xmsOTjggnvoOVKL49JXek'},
#  {'license': 1,
#   'file_name': 'Video 2 ezgif-frame-001 (59).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 6,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fd6860034-413c-52be-a5e3-d1b1f4de1bc7-Video%202%20ezgif-frame-001%20(59).jpg?Expires=1673986338673&KeyName=labelbox-assets-key-3&Signature=8VBXRDYFzvof5KnTke4qXK3nKwc'},
#  {'license': 1,
#   'file_name': 'Video 2 ezgif-frame-001 (61).jpg',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 7,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2

#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F70d04f29-5580-9e8b-4245-8f73ba375c69-VIdeo%204%20ezgif-frame-001%20(59).jpg?Expires=1673986338656&KeyName=labelbox-assets-key-3&Signature=rdIGtRyXk4mpGyqCxKr1cmkTSqo'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (60).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 110,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fd3490569-601a-6092-ab61-8e51619ef698-VIdeo%204%20ezgif-frame-001%20(60).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=7fmTbsIOtffn09CVRsyhyOgFqOM'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (61).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 111,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fc47eed55-6140-17f5-1fa2-46233ea55cf5-VIdeo%204%20ezgif-frame-001%20(61).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=gHaMxscq3rlEd6UnthoS4rmP8LY'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (62).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 112,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F9cb176dd-8923-f8a8-6fd6-16f63156adec-VIdeo%204%20ezgif-frame-001%20(62).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=_x4P3TiLPV7qP8RIMGJ5VHiVXyA'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (63).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 113,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F60e32873-d6cd-7353-1c34-9d3f10d0c30e-VIdeo%204%20ezgif-frame-001%20(63).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=Fv7DLe9TXZIgbLHyIMNwQ4oOw_s'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (64).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 114,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F82d1c4c8-df88-1dde-e324-7ae7ebb6b325-VIdeo%204%20ezgif-frame-001%20(64).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=BHW4Vi8hVyXLvpl-7MQ3Eh4fzBo'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (65).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 115,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F1b66ab4a-8f6b-0ada-e545-b3953614746e-VIdeo%204%20ezgif-frame-001%20(65).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=asIdcjNhicU8Wm1V4uDcXJ5Tsko'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (66).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 116,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F8f6c6a74-62a5-d555-c013-29684efc7698-VIdeo%204%20ezgif-frame-001%20(66).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=V_4kIIm_CVwZ3VocnSEli-zkMa4'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (67).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 117,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fb5f292e2-2e99-0dc2-b255-2d0a138660cf-VIdeo%204%20ezgif-frame-001%20(67).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=_OHLRArFf-1MYiBnU-3KF5CFR9M'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (68).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 118,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F11175fdb-96b7-fa46-2e1b-f01c3f75d334-VIdeo%204%20ezgif-frame-001%20(68).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=i0N9QZtqVbkaJgEgdEHuJmHB-Hk'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (69).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 119,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Feef79692-f764-e80f-8b88-e26d18a95f4a-VIdeo%204%20ezgif-frame-001%20(69).jpg?Expires=1673986338655&KeyName=labelbox-assets-key-3&Signature=J2kT3CjGpNWAIuliyiJXBCtTrzs'},
#  {'license': 1,
#   'file_name': 'VIdeo 4 ezgif-frame-001 (70).jpg',
#   'height': 1080,
#   'width': 1920,
#   'date_captured': '2022-07-14 12:59:58',
#   'id': 120,
# ...
#   'date_captured': '2022-08-22 12:27:26',
#   'id': 960,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fe5bdf22b-1551-5b8b-4e7e-e29fc2f28633-up87.png?Expires=1673986338468&KeyName=labelbox-assets-key-3&Signature=hWzvOZo5lrwb9n2CYRwxbCReFgA'},
#  {'license': 1,
#   'file_name': 'up88.png',
#   'height': 1920,
#   'width': 1080,
#   'date_captured': '2022

#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F91a6589e-3b4e-cc30-cfbc-d90dc7237da6-birs_eye_and_extended_Sequence%2001025.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=FPWluZj7_9XaaaMMYzlyZh7k7BU'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01023.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 987,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fb1f3c548-0edd-1509-f3f0-a5291e3b9b4f-birs_eye_and_extended_Sequence%2001023.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=j-qimE4vVrQIsR0PDUbeuwgxiGw'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01026.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 988,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F94ac2c05-88a4-2202-a031-8045b085394e-birs_eye_and_extended_Sequence%2001026.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=ajK6pb1jvpJoiPibLlJjTJNyrKo'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01027.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 989,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F6b3b8afb-000d-9fa5-a62d-8f374b735857-birs_eye_and_extended_Sequence%2001027.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=IRh1_OtevE5jpvuAZp231VG3-DE'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01028.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 990,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F02288143-1489-0775-611e-841fd27a2cfc-birs_eye_and_extended_Sequence%2001028.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=cVfo4OFBxN3BmjgidHh_qI8FiEc'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01029.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 991,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F661efbb3-f221-c700-5c3e-3250d6998727-birs_eye_and_extended_Sequence%2001029.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=A8dR_Xdex8G716gtlXtfGYUs1ds'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01030.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 992,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F51a46e2f-111c-6aa9-20e9-f034fcb4e219-birs_eye_and_extended_Sequence%2001030.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=r4JChfJ85exmDtDVZ2gvlLrlvwQ'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01031.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 993,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F49086958-3c13-b319-a7e9-15ce9a109358-birs_eye_and_extended_Sequence%2001031.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=L-_KikDZolma1H1y2bT0EpshGjY'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01032.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 994,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F8d7781af-97e9-984d-6808-c5d6f4440ec8-birs_eye_and_extended_Sequence%2001032.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=DKHZu6ef_s8aP_FRFRCOybEBr_g'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01033.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 995,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fa772fb7b-8b6b-5abe-ec77-fd26c7e15bcd-birs_eye_and_extended_Sequence%2001033.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=i_Xg67TzG9JaD89mixYGe3pPEQQ'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01034.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 996,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F9ae0f3dc-218b-84e2-48d1-0663bf5aec33-birs_eye_and_extended_Sequence%2001034.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=DJlbtaYE6xF0m-Q4-qGSCM2XHl0'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01035.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 997,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F44ef2241-37f6-b4cf-2264-ed721bbb692b-birs_eye_and_extended_Sequence%2001035.jpg?Expires=1673986338463&KeyName=labelbox-assets-key-3&Signature=8aJaeHqYoyKg7zS7EIvNndGUz9o'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01036.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 998,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2Fce8f1786-d974-8863-e084-cea750031cb1-birs_eye_and_extended_Sequence%2001036.jpg?Expires=1673986338462&KeyName=labelbox-assets-key-3&Signature=d9xhJ6seS7iDw1QSM2HZ7E9kPXA'},
#  {'license': 1,
#   'file_name': 'birs_eye_and_extended_Sequence 01037.jpg',
#   'height': 1080,
#   'width': 1620,
#   'date_captured': '2022-10-14 08:15:27',
#   'id': 999,
#   'coco_url': 'https://storage.labelbox.com/cl5jgpg6c2fs508ub88aa3748%2F8af2285b-a609-4c76-2f5d-8d3817006164-birs_eye_and_extended_Sequence%2001037.jpg?Expires=1673986338462&KeyName=labelbox-assets-key-3&Signature=TUmRXsrXGop4GJVj1tNEA6E8joA'},
#  ...]

# %%
from urllib.request import urlopen
import tqdm

# %%
for img in tqdm.tqdm(train["images"]):
    response = urlopen(img["coco_url"])
    data = response.read()
    with open("img/" + img["file_name"], "wb") as file:
        file.write(data)
        file.close()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 1187/1187 [13:20<00:00,  1.48it/s]
