# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Sanjiv/IMP-OIC-Windowing
import pandas as pd
#import numpy as np
import sys
import os
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Sanjiv/IMP-OIC-Windowing

# %%
ds = pd.read_csv('STAR_eval/question_answers.csv')
ds.dropna(inplace=True)
ds.head()
# Out:
#       Unnamed: 0         question_id  \
# 4846        6810  Feasibility_T5_981
#
#                                                question video_id  start  end  \
# 4846  Which object is the person able to hold after ...    IO712    0.0  5.9
#
#          answer                                            choices  \
# 4846  The book.  [{'choice_id': 0, 'choice': 'The book.', 'choi...
#
#                                             OIC_context  \
# 4846  In frame 0: man_02b0 wearing shirt_df93.man_02...
#
#                                              OIC_answer
# 4846  Based on the description given, there is no me...

# %%
import string
import time

q_ids = ds['question_id'].unique()

for q in q_ids:
  que = ds.query("question_id == '"+q+"'")
  answer = que['answer'].values[0].lower().strip('the ').translate(str.maketrans('', '', string.punctuation))
  OIC_answer = que['OIC_answer'].values[0]
  if answer not in OIC_answer:
    ds.loc[ds['question_id'] == q, 'Match'] = 'Wrong'
  else:
    ds.loc[ds['question_id'] == q, 'Match'] = 'Correct'

ds.to_csv('STAR_eval/question_answers_checked'+str(time.time())+'.csv')
ds.head()
# Out:
#       Unnamed: 0         question_id  \
# 4846        6810  Feasibility_T5_981
#
#                                                question video_id  start  end  \
# 4846  Which object is the person able to hold after ...    IO712    0.0  5.9
#
#          answer                                            choices  \
# 4846  The book.  [{'choice_id': 0, 'choice': 'The book.', 'choi...
#
#                                             OIC_context  \
# 4846  In frame 0: man_02b0 wearing shirt_df93.man_02...
#
#                                              OIC_answer    Match
# 4846  Based on the description given, there is no me...  Correct

# %%
import shutil

shutil.rmtree('temp')
