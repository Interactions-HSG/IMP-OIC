# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import os
#os.chdir('/content/drive/MyDrive/name/IMP-OIC-Windowing')
#from utils.extractframes import FrameExtractor
#import graphene
directory_path = 'how2QA/videos'
#from gpt_ask import run_gpt

final_df = pd.read_csv('how2QA/questions/how2QA_test_public_release.csv', )
subtitles= pd.read_json('how2QA/how2r_qa_sub.jsonl', lines=True)



#final_df = pd.concat([df1.T, df2.T,df3.T], ignore_index=True)
main = final_df.fillna('')
main.columns = ["video_names", "duration", "option1", "option2", "option3", "question", "answer"]
print(len( main['video_names'].unique()))
# Out:
# 1100

# %%
#download the videos
from pytube import YouTube
path="how2QA/videos/"
import yt_dlp

def downloadYouTube(video_id, output_path):

    if not os.path.exists(f'{output_path}{video_id}.mp4'):
        ydl_opts = {
            'format': 'bestvideo+bestaudio/best',
            'outtmpl': f'{output_path}{video_id}.%(ext)s',  # Save with video title
            'merge_output_format': 'mp4',  # Ensure merged output
            'cookiesfrombrowser': ('chrome',) #allow to access login details from the chrome to try download videos
        }
    
        #if not os.path.exists(output_path):
            #os.makedirs(output_path)

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download(["https://www.youtube.com/watch?v={}".format(video_id)])

private_not_found_videos = []
    
v_ids = main['video_names'].unique()
for v_id in v_ids:
    try:
        downloadYouTube(v_id, path)
        
    except Exception:
        private_not_found_videos.append(v_id)
        print('could not download '+v_id)

with open('how2QA/private_not_found_videos.txt', 'w') as file:
    for item in private_not_found_videos:
        file.write(f"{item}\n")
# Out:
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yKFdxnNGogQ
# [youtube] yKFdxnNGogQ: Downloading webpage
# [youtube] yKFdxnNGogQ: Downloading tv client config
# [youtube] yKFdxnNGogQ: Downloading player 9a279502-main
# [youtube] yKFdxnNGogQ: Downloading tv player API JSON
# ERROR: [youtube] yKFdxnNGogQ: Video unavailable
# could not download yKFdxnNGogQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0bn12M7mbsQ
# [youtube] 0bn12M7mbsQ: Downloading webpage
# [youtube] 0bn12M7mbsQ: Downloading tv client config
# [youtube] 0bn12M7mbsQ: Downloading player 9a279502-main
# [youtube] 0bn12M7mbsQ: Downloading tv player API JSON
# ERROR: [youtube] 0bn12M7mbsQ: Video unavailable. This video is private
# could not download 0bn12M7mbsQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=i93bqYLsMQg
# [youtube] i93bqYLsMQg: Downloading webpage
# [youtube] i93bqYLsMQg: Downloading tv client config
# [youtube] i93bqYLsMQg: Downloading player 9a279502-main
# [youtube] i93bqYLsMQg: Downloading tv player API JSON
# ERROR: [youtube] i93bqYLsMQg: Video unavailable. This video is private
# could not download i93bqYLsMQg
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MeEb0KmU8xQ
# [youtube] MeEb0KmU8xQ: Downloading webpage
# [youtube] MeEb0KmU8xQ: Downloading tv client config
# [youtube] MeEb0KmU8xQ: Downloading player 9a279502-main
# [youtube] MeEb0KmU8xQ: Downloading tv player API JSON
# ERROR: [youtube] MeEb0KmU8xQ: Video unavailable
# could not download MeEb0KmU8xQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=o4B4vvmdNis
# [youtube] o4B4vvmdNis: Downloading webpage
# [youtube] o4B4vvmdNis: Downloading tv client config
# [youtube] o4B4vvmdNis: Downloading player 9a279502-main
# [youtube] o4B4vvmdNis: Downloading tv player API JSON
# ERROR: [youtube] o4B4vvmdNis: Video unavailable. This video is private
# could not download o4B4vvmdNis
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=netWuKuqJ68
# [youtube] netWuKuqJ68: Downloading webpage
# [youtube] netWuKuqJ68: Downloading tv client config
# [youtube] netWuKuqJ68: Downloading player 9a279502-main
# [youtube] netWuKuqJ68: Downloading tv player API JSON
# ERROR: [youtube] netWuKuqJ68: Video unavailable. This video is private
# could not download netWuKuqJ68
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gOvaW9bfUuY
# [youtube] gOvaW9bfUuY: Downloading webpage
# [youtube] gOvaW9bfUuY: Downloading tv client config
# [youtube] gOvaW9bfUuY: Downloading player 9a279502-main
# [youtube] gOvaW9bfUuY: Downloading tv player API JSON
# ERROR: [youtube] gOvaW9bfUuY: Video unavailable
# could not download gOvaW9bfUuY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uBbihzWDlAw
# [youtube] uBbihzWDlAw: Downloading webpage
# [youtube] uBbihzWDlAw: Downloading tv client config
# [youtube] uBbihzWDlAw: Downloading player 9a279502-main
# [youtube] uBbihzWDlAw: Downloading tv player API JSON
# ERROR: [youtube] uBbihzWDlAw: Video unavailable
# could not download uBbihzWDlAw
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ziCR9k6qHWE
# [youtube] ziCR9k6qHWE: Downloading webpage
# [youtube] ziCR9k6qHWE: Downloading tv client config
# [youtube] ziCR9k6qHWE: Downloading player 9a279502-main
# [youtube] ziCR9k6qHWE: Downloading tv player API JSON
# ERROR: [youtube] ziCR9k6qHWE: Video unavailable. This video is private
# could not download ziCR9k6qHWE
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qUk2vjbqZOs
# [youtube] qUk2vjbqZOs: Downloading webpage
# [youtube] qUk2vjbqZOs: Downloading tv client config
# [youtube] qUk2vjbqZOs: Downloading player 9a279502-main
# [youtube] qUk2vjbqZOs: Downloading tv player API JSON
# ERROR: [youtube] qUk2vjbqZOs: Video unavailable. This video is private
# could not download qUk2vjbqZOs
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uXaCsvH30ds
# [youtube] uXaCsvH30ds: Downloading webpage
# [youtube] uXaCsvH30ds: Downloading tv client config
# [youtube] uXaCsvH30ds: Downloading player 9a279502-main
# [youtube] uXaCsvH30ds: Downloading tv player API JSON
# ERROR: [youtube] uXaCsvH30ds: This video has been removed for violating YouTube's Terms of Service
# could not download uXaCsvH30ds
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=W6u_bC-Mm58
# [youtube] W6u_bC-Mm58: Downloading webpage
# [youtube] W6u_bC-Mm58: Downloading tv client config
# [youtube] W6u_bC-Mm58: Downloading player 9a279502-main
# [youtube] W6u_bC-Mm58: Downloading tv player API JSON
# ERROR: [youtube] W6u_bC-Mm58: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download W6u_bC-Mm58
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Z828msUoQG4
# [youtube] Z828msUoQG4: Downloading webpage
# [youtube] Z828msUoQG4: Downloading tv client config
# [youtube] Z828msUoQG4: Downloading player 9a279502-main
# [youtube] Z828msUoQG4: Downloading tv player API JSON
# ERROR: [youtube] Z828msUoQG4: Video unavailable
# could not download Z828msUoQG4
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_DVStVNEAE8
# [youtube] _DVStVNEAE8: Downloading webpage
# [youtube] _DVStVNEAE8: Downloading tv client config
# [youtube] _DVStVNEAE8: Downloading player 9a279502-main
# [youtube] _DVStVNEAE8: Downloading tv player API JSON
# ERROR: [youtube] _DVStVNEAE8: Video unavailable
# could not download _DVStVNEAE8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NN4GKUGNBp4
# [youtube] NN4GKUGNBp4: Downloading webpage
# [youtube] NN4GKUGNBp4: Downloading tv client config
# [youtube] NN4GKUGNBp4: Downloading player 9a279502-main
# [youtube] NN4GKUGNBp4: Downloading tv player API JSON
# ERROR: [youtube] NN4GKUGNBp4: Video unavailable
# could not download NN4GKUGNBp4
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NjVsuK4WJpk
# [youtube] NjVsuK4WJpk: Downloading webpage
# [youtube] NjVsuK4WJpk: Downloading tv client config
# [youtube] NjVsuK4WJpk: Downloading player 9a279502-main
# [youtube] NjVsuK4WJpk: Downloading tv player API JSON
# ERROR: [youtube] NjVsuK4WJpk: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download NjVsuK4WJpk
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ifDYnH0y1UQ
# [youtube] ifDYnH0y1UQ: Downloading webpage
# [youtube] ifDYnH0y1UQ: Downloading tv client config
# [youtube] ifDYnH0y1UQ: Downloading player 9a279502-main
# [youtube] ifDYnH0y1UQ: Downloading tv player API JSON
# ERROR: [youtube] ifDYnH0y1UQ: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download ifDYnH0y1UQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iiWObB7diuU
# [youtube] iiWObB7diuU: Downloading webpage
# [youtube] iiWObB7diuU: Downloading tv client config
# [youtube] iiWObB7diuU: Downloading player 9a279502-main
# [youtube] iiWObB7diuU: Downloading tv player API JSON
# ERROR: [youtube] iiWObB7diuU: Video unavailable. This video is private
# could not download iiWObB7diuU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AHbo7afT26w
# [youtube] AHbo7afT26w: Downloading webpage
# [youtube] AHbo7afT26w: Downloading tv client config
# [youtube] AHbo7afT26w: Downloading player 9a279502-main
# [youtube] AHbo7afT26w: Downloading tv player API JSON
# ERROR: [youtube] AHbo7afT26w: Video unavailable. This video is private
# could not download AHbo7afT26w
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mrJiWGNmsxA
# [youtube] mrJiWGNmsxA: Downloading webpage
# [youtube] mrJiWGNmsxA: Downloading tv client config
# [youtube] mrJiWGNmsxA: Downloading player 9a279502-main
# [youtube] mrJiWGNmsxA: Downloading tv player API JSON
# ERROR: [youtube] mrJiWGNmsxA: Video unavailable
# could not download mrJiWGNmsxA
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VK3eBrM5cLE
# [youtube] VK3eBrM5cLE: Downloading webpage
# [youtube] VK3eBrM5cLE: Downloading tv client config
# [youtube] VK3eBrM5cLE: Downloading player 9a279502-main
# [youtube] VK3eBrM5cLE: Downloading tv player API JSON
# ERROR: [youtube] VK3eBrM5cLE: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download VK3eBrM5cLE
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GpsvOe5ODRs
# [youtube] GpsvOe5ODRs: Downloading webpage
# [youtube] GpsvOe5ODRs: Downloading tv client config
# [youtube] GpsvOe5ODRs: Downloading player 9a279502-main
# [youtube] GpsvOe5ODRs: Downloading tv player API JSON
# ERROR: [youtube] GpsvOe5ODRs: Video unavailable
# could not download GpsvOe5ODRs
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UvWQWS0JYvQ
# [youtube] UvWQWS0JYvQ: Downloading webpage
# [youtube] UvWQWS0JYvQ: Downloading tv client config
# [youtube] UvWQWS0JYvQ: Downloading player 9a279502-main
# [youtube] UvWQWS0JYvQ: Downloading tv player API JSON
# ERROR: [youtube] UvWQWS0JYvQ: Video unavailable
# could not download UvWQWS0JYvQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UpwlnaUwnoQ
# [youtube] UpwlnaUwnoQ: Downloading webpage
# [youtube] UpwlnaUwnoQ: Downloading tv client config
# [youtube] UpwlnaUwnoQ: Downloading player 9a279502-main
# [youtube] UpwlnaUwnoQ: Downloading tv player API JSON
# ERROR: [youtube] UpwlnaUwnoQ: Video unavailable. This video is private
# could not download UpwlnaUwnoQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oUTJzHGexOI
# [youtube] oUTJzHGexOI: Downloading webpage
# [youtube] oUTJzHGexOI: Downloading tv client config
# [youtube] oUTJzHGexOI: Downloading player 9a279502-main
# [youtube] oUTJzHGexOI: Downloading tv player API JSON
# ERROR: [youtube] oUTJzHGexOI: Video unavailable
# could not download oUTJzHGexOI
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PSeib60mXyU
# [youtube] PSeib60mXyU: Downloading webpage
# [youtube] PSeib60mXyU: Downloading tv client config
# [youtube] PSeib60mXyU: Downloading player 9a279502-main
# [youtube] PSeib60mXyU: Downloading tv player API JSON
# ERROR: [youtube] PSeib60mXyU: Video unavailable. This video is private
# could not download PSeib60mXyU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=28XwFimv1Hk
# [youtube] 28XwFimv1Hk: Downloading webpage
# [youtube] 28XwFimv1Hk: Downloading tv client config
# [youtube] 28XwFimv1Hk: Downloading player 9a279502-main
# [youtube] 28XwFimv1Hk: Downloading tv player API JSON
# ERROR: [youtube] 28XwFimv1Hk: Video unavailable. This video is private
# could not download 28XwFimv1Hk
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LmWO4xMg4Es
# [youtube] LmWO4xMg4Es: Downloading webpage
# [youtube] LmWO4xMg4Es: Downloading tv client config
# [youtube] LmWO4xMg4Es: Downloading player 9a279502-main
# [youtube] LmWO4xMg4Es: Downloading tv player API JSON
# ERROR: [youtube] LmWO4xMg4Es: Video unavailable. This video is private
# could not download LmWO4xMg4Es
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZOdJ-S7cXUs
# [youtube] ZOdJ-S7cXUs: Downloading webpage
# [youtube] ZOdJ-S7cXUs: Downloading tv client config
# [youtube] ZOdJ-S7cXUs: Downloading player 9a279502-main
# [youtube] ZOdJ-S7cXUs: Downloading tv player API JSON
# ERROR: [youtube] ZOdJ-S7cXUs: Video unavailable. This video is private
# could not download ZOdJ-S7cXUs
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ri9oc7Aq5Q8
# [youtube] ri9oc7Aq5Q8: Downloading webpage
# [youtube] ri9oc7Aq5Q8: Downloading tv client config
# [youtube] ri9oc7Aq5Q8: Downloading player 9a279502-main
# [youtube] ri9oc7Aq5Q8: Downloading tv player API JSON
# ERROR: [youtube] ri9oc7Aq5Q8: Video unavailable
# could not download ri9oc7Aq5Q8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oq7qGkNsx6c
# [youtube] oq7qGkNsx6c: Downloading webpage
# [youtube] oq7qGkNsx6c: Downloading tv client config
# [youtube] oq7qGkNsx6c: Downloading player 9a279502-main
# [youtube] oq7qGkNsx6c: Downloading tv player API JSON
# ERROR: [youtube] oq7qGkNsx6c: Video unavailable. This video is private
# could not download oq7qGkNsx6c
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kLPgLejnEIU
# [youtube] kLPgLejnEIU: Downloading webpage
# [youtube] kLPgLejnEIU: Downloading tv client config
# [youtube] kLPgLejnEIU: Downloading player 9a279502-main
# [youtube] kLPgLejnEIU: Downloading tv player API JSON
# ERROR: [youtube] kLPgLejnEIU: Video unavailable. This video is private
# could not download kLPgLejnEIU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fWzFG1t68aQ
# [youtube] fWzFG1t68aQ: Downloading webpage
# [youtube] fWzFG1t68aQ: Downloading tv client config
# [youtube] fWzFG1t68aQ: Downloading player 9a279502-main
# [youtube] fWzFG1t68aQ: Downloading tv player API JSON
# ERROR: [youtube] fWzFG1t68aQ: Video unavailable
# could not download fWzFG1t68aQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HVAPSysxD9Y
# [youtube] HVAPSysxD9Y: Downloading webpage
# [youtube] HVAPSysxD9Y: Downloading tv client config
# [youtube] HVAPSysxD9Y: Downloading player 9a279502-main
# [youtube] HVAPSysxD9Y: Downloading tv player API JSON
# ERROR: [youtube] HVAPSysxD9Y: Video unavailable. This video is private
# could not download HVAPSysxD9Y
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MiTYMmqUJQA
# [youtube] MiTYMmqUJQA: Downloading webpage
# [youtube] MiTYMmqUJQA: Downloading tv client config
# [youtube] MiTYMmqUJQA: Downloading player 9a279502-main
# [youtube] MiTYMmqUJQA: Downloading tv player API JSON
# ERROR: [youtube] MiTYMmqUJQA: Video unavailable. This video is private
# could not download MiTYMmqUJQA
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=C6QZ-CsoFSc
# [youtube] C6QZ-CsoFSc: Downloading webpage
# [youtube] C6QZ-CsoFSc: Downloading tv client config
# [youtube] C6QZ-CsoFSc: Downloading player 9a279502-main
# [youtube] C6QZ-CsoFSc: Downloading tv player API JSON
# ERROR: [youtube] C6QZ-CsoFSc: Video unavailable. This video is private
# could not download C6QZ-CsoFSc
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PQNUkMaReuQ
# [youtube] PQNUkMaReuQ: Downloading webpage
# [youtube] PQNUkMaReuQ: Downloading tv client config
# [youtube] PQNUkMaReuQ: Downloading player 9a279502-main
# [youtube] PQNUkMaReuQ: Downloading tv player API JSON
# ERROR: [youtube] PQNUkMaReuQ: Video unavailable. This video is private
# could not download PQNUkMaReuQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T6iHfuqq5ek
# [youtube] T6iHfuqq5ek: Downloading webpage
# [youtube] T6iHfuqq5ek: Downloading tv client config
# [youtube] T6iHfuqq5ek: Downloading player 9a279502-main
# [youtube] T6iHfuqq5ek: Downloading tv player API JSON
# ERROR: [youtube] T6iHfuqq5ek: Video unavailable
# could not download T6iHfuqq5ek
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=59FLgd-gQxU
# [youtube] 59FLgd-gQxU: Downloading webpage
# [youtube] 59FLgd-gQxU: Downloading tv client config
# [youtube] 59FLgd-gQxU: Downloading player 9a279502-main
# [youtube] 59FLgd-gQxU: Downloading tv player API JSON
# ERROR: [youtube] 59FLgd-gQxU: Video unavailable. This video is private
# could not download 59FLgd-gQxU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Saxk3x-0tw8
# [youtube] Saxk3x-0tw8: Downloading webpage
# [youtube] Saxk3x-0tw8: Downloading tv client config
# [youtube] Saxk3x-0tw8: Downloading player 9a279502-main
# [youtube] Saxk3x-0tw8: Downloading tv player API JSON
# ERROR: [youtube] Saxk3x-0tw8: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download Saxk3x-0tw8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fWGWLqZQqD4
# [youtube] fWGWLqZQqD4: Downloading webpage
# [youtube] fWGWLqZQqD4: Downloading tv client config
# [youtube] fWGWLqZQqD4: Downloading player 9a279502-main
# [youtube] fWGWLqZQqD4: Downloading tv player API JSON
# ERROR: [youtube] fWGWLqZQqD4: Video unavailable. This video is no longer available because the YouTube account associated with this video has been terminated.
# could not download fWGWLqZQqD4
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iNINjyMDTRA
# [youtube] iNINjyMDTRA: Downloading webpage
# [youtube] iNINjyMDTRA: Downloading tv client config
# [youtube] iNINjyMDTRA: Downloading player 9a279502-main
# [youtube] iNINjyMDTRA: Downloading tv player API JSON
# ERROR: [youtube] iNINjyMDTRA: Video unavailable. This video is private
# could not download iNINjyMDTRA
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iVrMGvqpTi8
# [youtube] iVrMGvqpTi8: Downloading webpage
# [youtube] iVrMGvqpTi8: Downloading tv client config
# [youtube] iVrMGvqpTi8: Downloading player 9a279502-main
# [youtube] iVrMGvqpTi8: Downloading tv player API JSON
# ERROR: [youtube] iVrMGvqpTi8: Video unavailable
# could not download iVrMGvqpTi8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=czpC81KlE9U
# [youtube] czpC81KlE9U: Downloading webpage
# [youtube] czpC81KlE9U: Downloading tv client config
# [youtube] czpC81KlE9U: Downloading player 9a279502-main
# [youtube] czpC81KlE9U: Downloading tv player API JSON
# ERROR: [youtube] czpC81KlE9U: Video unavailable
# could not download czpC81KlE9U
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hAuKdJOXUfE
# [youtube] hAuKdJOXUfE: Downloading webpage
# [youtube] hAuKdJOXUfE: Downloading tv client config
# [youtube] hAuKdJOXUfE: Downloading player 9a279502-main
# [youtube] hAuKdJOXUfE: Downloading tv player API JSON
# ERROR: [youtube] hAuKdJOXUfE: Video unavailable
# could not download hAuKdJOXUfE
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=w-dZRTCYLz0
# [youtube] w-dZRTCYLz0: Downloading webpage
# [youtube] w-dZRTCYLz0: Downloading tv client config
# [youtube] w-dZRTCYLz0: Downloading player 9a279502-main
# [youtube] w-dZRTCYLz0: Downloading tv player API JSON
# ERROR: [youtube] w-dZRTCYLz0: Video unavailable
# could not download w-dZRTCYLz0
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nHxrpGsk-dQ
# [youtube] nHxrpGsk-dQ: Downloading webpage
# [youtube] nHxrpGsk-dQ: Downloading tv client config
# [youtube] nHxrpGsk-dQ: Downloading player 9a279502-main
# [youtube] nHxrpGsk-dQ: Downloading tv player API JSON
# ERROR: [youtube] nHxrpGsk-dQ: Video unavailable
# could not download nHxrpGsk-dQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OAFjb4n7Mo0
# [youtube] OAFjb4n7Mo0: Downloading webpage
# [youtube] OAFjb4n7Mo0: Downloading tv client config
# [youtube] OAFjb4n7Mo0: Downloading player 9a279502-main
# [youtube] OAFjb4n7Mo0: Downloading tv player API JSON
# ERROR: [youtube] OAFjb4n7Mo0: Video unavailable. This video is private
# could not download OAFjb4n7Mo0
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xPITGjJqdxI
# [youtube] xPITGjJqdxI: Downloading webpage
# [youtube] xPITGjJqdxI: Downloading tv client config
# [youtube] xPITGjJqdxI: Downloading player 9a279502-main
# [youtube] xPITGjJqdxI: Downloading tv player API JSON
# ERROR: [youtube] xPITGjJqdxI: This video has been removed for violating YouTube's policy on spam, deceptive practices, and scams
# could not download xPITGjJqdxI
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=d0u47KDUcCU
# [youtube] d0u47KDUcCU: Downloading webpage
# [youtube] d0u47KDUcCU: Downloading tv client config
# [youtube] d0u47KDUcCU: Downloading player 9a279502-main
# [youtube] d0u47KDUcCU: Downloading tv player API JSON
# ERROR: [youtube] d0u47KDUcCU: Video unavailable
# could not download d0u47KDUcCU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kn1Hg2lSTe0
# [youtube] kn1Hg2lSTe0: Downloading webpage
# [youtube] kn1Hg2lSTe0: Downloading tv client config
# [youtube] kn1Hg2lSTe0: Downloading player 9a279502-main
# [youtube] kn1Hg2lSTe0: Downloading tv player API JSON
# ERROR: [youtube] kn1Hg2lSTe0: Video unavailable. This video is private
# could not download kn1Hg2lSTe0
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jdoK7ERPd8Y
# [youtube] jdoK7ERPd8Y: Downloading webpage
# [youtube] jdoK7ERPd8Y: Downloading tv client config
# [youtube] jdoK7ERPd8Y: Downloading player 9a279502-main
# [youtube] jdoK7ERPd8Y: Downloading tv player API JSON
# ERROR: [youtube] jdoK7ERPd8Y: Video unavailable. This video is private
# could not download jdoK7ERPd8Y
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0YXbmCk_9-0
# [youtube] 0YXbmCk_9-0: Downloading webpage
# [youtube] 0YXbmCk_9-0: Downloading tv client config
# [youtube] 0YXbmCk_9-0: Downloading player 9a279502-main
# [youtube] 0YXbmCk_9-0: Downloading tv player API JSON
# ERROR: [youtube] 0YXbmCk_9-0: Video unavailable
# could not download 0YXbmCk_9-0
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FD2ziStXgJM
# [youtube] FD2ziStXgJM: Downloading webpage
# [youtube] FD2ziStXgJM: Downloading tv client config
# [youtube] FD2ziStXgJM: Downloading player 9a279502-main
# [youtube] FD2ziStXgJM: Downloading tv player API JSON
# ERROR: [youtube] FD2ziStXgJM: Video unavailable. This video is private
# could not download FD2ziStXgJM
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Bsm8s-ueIvA
# [youtube] Bsm8s-ueIvA: Downloading webpage
# [youtube] Bsm8s-ueIvA: Downloading tv client config
# [youtube] Bsm8s-ueIvA: Downloading player 9a279502-main
# [youtube] Bsm8s-ueIvA: Downloading tv player API JSON
# ERROR: [youtube] Bsm8s-ueIvA: Video unavailable
# could not download Bsm8s-ueIvA
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=edM1Ds0lr7Y
# [youtube] edM1Ds0lr7Y: Downloading webpage
# [youtube] edM1Ds0lr7Y: Downloading tv client config
# [youtube] edM1Ds0lr7Y: Downloading player 9a279502-main
# [youtube] edM1Ds0lr7Y: Downloading tv player API JSON
# ERROR: [youtube] edM1Ds0lr7Y: Video unavailable
# could not download edM1Ds0lr7Y
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JVf0Y7WJsfA
# [youtube] JVf0Y7WJsfA: Downloading webpage
# [youtube] JVf0Y7WJsfA: Downloading tv client config
# [youtube] JVf0Y7WJsfA: Downloading player 9a279502-main
# [youtube] JVf0Y7WJsfA: Downloading tv player API JSON
# ERROR: [youtube] JVf0Y7WJsfA: Video unavailable
# could not download JVf0Y7WJsfA
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jG7vhMMXagQ
# [youtube] jG7vhMMXagQ: Downloading webpage
# [youtube] jG7vhMMXagQ: Downloading tv client config
# [youtube] jG7vhMMXagQ: Downloading player 9a279502-main
# [youtube] jG7vhMMXagQ: Downloading tv player API JSON
# ERROR: [youtube] jG7vhMMXagQ: Video unavailable. This video is private
# could not download jG7vhMMXagQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lSQCI0AFbTY
# [youtube] lSQCI0AFbTY: Downloading webpage
# [youtube] lSQCI0AFbTY: Downloading tv client config
# [youtube] lSQCI0AFbTY: Downloading player 9a279502-main
# [youtube] lSQCI0AFbTY: Downloading tv player API JSON
# ERROR: [youtube] lSQCI0AFbTY: Video unavailable
# could not download lSQCI0AFbTY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YYGxd4JoXIY
# [youtube] YYGxd4JoXIY: Downloading webpage
# [youtube] YYGxd4JoXIY: Downloading tv client config
# [youtube] YYGxd4JoXIY: Downloading player 9a279502-main
# [youtube] YYGxd4JoXIY: Downloading tv player API JSON
# ERROR: [youtube] YYGxd4JoXIY: Video unavailable. This video is private
# could not download YYGxd4JoXIY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3xJ8mmidCa8
# [youtube] 3xJ8mmidCa8: Downloading webpage
# [youtube] 3xJ8mmidCa8: Downloading tv client config
# [youtube] 3xJ8mmidCa8: Downloading player 9a279502-main
# [youtube] 3xJ8mmidCa8: Downloading tv player API JSON
# ERROR: [youtube] 3xJ8mmidCa8: Video unavailable. This video is private
# could not download 3xJ8mmidCa8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iTjtXIXBPac
# [youtube] iTjtXIXBPac: Downloading webpage
# [youtube] iTjtXIXBPac: Downloading tv client config
# [youtube] iTjtXIXBPac: Downloading player 9a279502-main
# [youtube] iTjtXIXBPac: Downloading tv player API JSON
# ERROR: [youtube] iTjtXIXBPac: Video unavailable
# could not download iTjtXIXBPac
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=f_hFV792kkU
# [youtube] f_hFV792kkU: Downloading webpage
# [youtube] f_hFV792kkU: Downloading tv client config
# [youtube] f_hFV792kkU: Downloading player 9a279502-main
# [youtube] f_hFV792kkU: Downloading tv player API JSON
# ERROR: [youtube] f_hFV792kkU: Video unavailable. This video is private
# could not download f_hFV792kkU
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=M-4Ts_QtQok
# [youtube] M-4Ts_QtQok: Downloading webpage
# [youtube] M-4Ts_QtQok: Downloading tv client config
# [youtube] M-4Ts_QtQok: Downloading player 9a279502-main
# [youtube] M-4Ts_QtQok: Downloading tv player API JSON
# ERROR: [youtube] M-4Ts_QtQok: Video unavailable. This video is private
# could not download M-4Ts_QtQok
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iaXJ8Jxu0Dw
# [youtube] iaXJ8Jxu0Dw: Downloading webpage
# [youtube] iaXJ8Jxu0Dw: Downloading tv client config
# [youtube] iaXJ8Jxu0Dw: Downloading player 9a279502-main
# [youtube] iaXJ8Jxu0Dw: Downloading tv player API JSON
# ERROR: [youtube] iaXJ8Jxu0Dw: Video unavailable
# could not download iaXJ8Jxu0Dw
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oOQ9_tszB2Y
# [youtube] oOQ9_tszB2Y: Downloading webpage
# [youtube] oOQ9_tszB2Y: Downloading tv client config
# [youtube] oOQ9_tszB2Y: Downloading player 9a279502-main
# [youtube] oOQ9_tszB2Y: Downloading tv player API JSON
# ERROR: [youtube] oOQ9_tszB2Y: Video unavailable
# could not download oOQ9_tszB2Y
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GBMTYySCpLY
# [youtube] GBMTYySCpLY: Downloading webpage
# [youtube] GBMTYySCpLY: Downloading tv client config
# [youtube] GBMTYySCpLY: Downloading player 9a279502-main
# [youtube] GBMTYySCpLY: Downloading tv player API JSON
# ERROR: [youtube] GBMTYySCpLY: Video unavailable
# could not download GBMTYySCpLY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HVIffFcNfXk
# [youtube] HVIffFcNfXk: Downloading webpage
# [youtube] HVIffFcNfXk: Downloading tv client config
# [youtube] HVIffFcNfXk: Downloading player 9a279502-main
# [youtube] HVIffFcNfXk: Downloading tv player API JSON
# ERROR: [youtube] HVIffFcNfXk: Video unavailable. This video is private
# could not download HVIffFcNfXk
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8VIbzKGT2ko
# [youtube] 8VIbzKGT2ko: Downloading webpage
# [youtube] 8VIbzKGT2ko: Downloading tv client config
# [youtube] 8VIbzKGT2ko: Downloading player 9a279502-main
# [youtube] 8VIbzKGT2ko: Downloading tv player API JSON
# ERROR: [youtube] 8VIbzKGT2ko: Video unavailable
# could not download 8VIbzKGT2ko
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2v6z4AqRwDc
# [youtube] 2v6z4AqRwDc: Downloading webpage
# [youtube] 2v6z4AqRwDc: Downloading tv client config
# [youtube] 2v6z4AqRwDc: Downloading player 9a279502-main
# [youtube] 2v6z4AqRwDc: Downloading tv player API JSON
# ERROR: [youtube] 2v6z4AqRwDc: Video unavailable. This video is private
# could not download 2v6z4AqRwDc
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LEgF1BZJQQE
# [youtube] LEgF1BZJQQE: Downloading webpage
# [youtube] LEgF1BZJQQE: Downloading tv client config
# [youtube] LEgF1BZJQQE: Downloading player 9a279502-main
# [youtube] LEgF1BZJQQE: Downloading tv player API JSON
# ERROR: [youtube] LEgF1BZJQQE: Video unavailable
# could not download LEgF1BZJQQE
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eXILCPt-dgQ
# [youtube] eXILCPt-dgQ: Downloading webpage
# [youtube] eXILCPt-dgQ: Downloading tv client config
# [youtube] eXILCPt-dgQ: Downloading player 9a279502-main
# [youtube] eXILCPt-dgQ: Downloading tv player API JSON
# ERROR: [youtube] eXILCPt-dgQ: Video unavailable. This video is private
# could not download eXILCPt-dgQ
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Z1a0AiLiCks
# [youtube] Z1a0AiLiCks: Downloading webpage
# [youtube] Z1a0AiLiCks: Downloading tv client config
# [youtube] Z1a0AiLiCks: Downloading player 9a279502-main
# [youtube] Z1a0AiLiCks: Downloading tv player API JSON
# ERROR: [youtube] Z1a0AiLiCks: Video unavailable. This video is private
# could not download Z1a0AiLiCks
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xpgHZygt5Hg
# [youtube] xpgHZygt5Hg: Downloading webpage
# [youtube] xpgHZygt5Hg: Downloading tv client config
# [youtube] xpgHZygt5Hg: Downloading player 9a279502-main
# [youtube] xpgHZygt5Hg: Downloading tv player API JSON
# ERROR: [youtube] xpgHZygt5Hg: Video unavailable
# could not download xpgHZygt5Hg
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=28ZFlYlPe_8
# [youtube] 28ZFlYlPe_8: Downloading webpage
# [youtube] 28ZFlYlPe_8: Downloading tv client config
# [youtube] 28ZFlYlPe_8: Downloading player 9a279502-main
# [youtube] 28ZFlYlPe_8: Downloading tv player API JSON
# ERROR: [youtube] 28ZFlYlPe_8: Video unavailable. This video is private
# could not download 28ZFlYlPe_8
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n77ljoWtIOY
# [youtube] n77ljoWtIOY: Downloading webpage
# [youtube] n77ljoWtIOY: Downloading tv client config
# [youtube] n77ljoWtIOY: Downloading player 9a279502-main
# [youtube] n77ljoWtIOY: Downloading tv player API JSON
# ERROR: [youtube] n77ljoWtIOY: Video unavailable. This video is private
# could not download n77ljoWtIOY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nOcsURgsLXY
# [youtube] nOcsURgsLXY: Downloading webpage
# [youtube] nOcsURgsLXY: Downloading tv client config
# [youtube] nOcsURgsLXY: Downloading player 9a279502-main
# [youtube] nOcsURgsLXY: Downloading tv player API JSON
# ERROR: [youtube] nOcsURgsLXY: Video unavailable. This video is private
# could not download nOcsURgsLXY
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_bNfgwPz_70
# [youtube] _bNfgwPz_70: Downloading webpage
# [youtube] _bNfgwPz_70: Downloading tv client config
# [youtube] _bNfgwPz_70: Downloading player 9a279502-main
# [youtube] _bNfgwPz_70: Downloading tv player API JSON
# ERROR: [youtube] _bNfgwPz_70: Video unavailable
# could not download _bNfgwPz_70
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KZp5gBtrW9c
# [youtube] KZp5gBtrW9c: Downloading webpage
# [youtube] KZp5gBtrW9c: Downloading tv client config
# [youtube] KZp5gBtrW9c: Downloading player 9a279502-main
# [youtube] KZp5gBtrW9c: Downloading tv player API JSON
# ERROR: [youtube] KZp5gBtrW9c: This video has been removed for violating YouTube's Terms of Service
# could not download KZp5gBtrW9c
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vL2egnIzPJs
# [youtube] vL2egnIzPJs: Downloading webpage
# [youtube] vL2egnIzPJs: Downloading tv client config
# [youtube] vL2egnIzPJs: Downloading player 9a279502-main
# [youtube] vL2egnIzPJs: Downloading tv player API JSON
# ERROR: [youtube] vL2egnIzPJs: Video unavailable
# could not download vL2egnIzPJs
# Extracting cookies from chrome
# Extracted 2969 cookies from chrome
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vXLyl6f7cmM
# [youtube] vXLyl6f7cmM: Downloading webpage
# [youtube] vXLyl6f7cmM: Downloading tv client config
# [youtube] vXLyl6f7cmM: Downloading player 9a279502-main
# [youtube] vXLyl6f7cmM: Downloading tv player API JSON
# ERROR: [youtube] vXLyl6f7cmM: Video unavailable. This video is private
# could not download vXLyl6f7cmM

# %%
# %pip install yt-dlp

# %%
diff =main.apply(lambda row: (int(row['end_time'])-int(row['start_time'])) if row['end_time'] and row['start_time'] else 0, axis=1).tolist()
diff

# %%
import ffmpeg

def segment_video(input_path, output_path, start, end):
    input_file = ffmpeg.input(directory_path+'/'+input_path+'.mp4')
    duration = int(end-start)
    print(duration)
    #if duration < 10:
    output_file = ffmpeg.output(input_file.trim(start=start, duration = duration).filter('setpts','PTS-STARTPTS'), filename=directory_path+'/trim/'+output_path+'.mp4')
    ffmpeg.run(output_file)
    return True
    #else:
      #return False

# %%
def run_oic(question_id, video_id , start, end):
    out_dir = "out"
    # check if the directory has a video file
    for video in os.scandir(directory_path):
        video_name=(video.name).split('.')[0]
        if video_name == video_id:
            #segment the video into a clip with the given start and end timestamp
            video_p = segment_video(video_name,str(question_id)+video_name,start,end)
            # if video exists, extract frames with windowing of few frames to improve the detection
            if video_p:
                ex = FrameExtractor(video_file=directory_path+'/trim/'+str(question_id)+video_name+'.mp4',fps_to_save=10, window_size=2)
                ex.main()
                
                # instantiate graphene "OIC core that runs RelTR"  
                g = graphene.Graphene(alpha=0.3, min_assignment_conf=0.6)
            
                # check if the out directory exists else create one
                if not os.path.isdir(out_dir):
                    os.mkdir(out_dir)
                
                # prepare output files 
                text = str(question_id)+video_name+'graph2text.txt'
                img_dir_path = '{}/trim/{}{}-opencv'.format(directory_path,str(question_id),video_name)  
                
                # classify images from the image directory
                g.classify_images_window(img_dir_path,5)
                
                # generate relationship graph
                graph_dir_path =  "{}/img/JSON".format(img_dir_path)
                g.generate_temporal_graph_frames_no_plot(scenegraphs_path=graph_dir_path, image_path= "{}/img".format(img_dir_path))

                # save textual output in the out directory
                g.tg.to_text(os.path.join(out_dir, text))

                if os.path.isfile(os.path.join(out_dir,text)):
                    with open(os.path.join(out_dir,text)) as f:
                        context = "".join(map(str,f.readlines()))
                        return str(context)
                else:
                    continue

# %% [markdown]
# import shutil
# shutil.rmtree('temp')

# %%
import math
print(main.shape[0])
main_liat=list(main['parent_video_id'])
not_found_vids = ['https://www.youtube.com/watch?v=W1_WorcmxPM',
'https://www.youtube.com/watch?v=2G5czNVhAJQ','https://www.youtube.com/watch?v=0FgFZIEt5YQ'
'https://www.youtube.com/watch?v=v0hJuq-WKnM',
'https://www.youtube.com/watch?v=JS60qyA1Kws',
'https://www.youtube.com/watch?v=8gamPx-DHAw',
'https://www.youtube.com/watch?v=aaweXw03kQI',
'https://www.youtube.com/watch?v=wM24NQYVZO8',
'https://www.youtube.com/watch?v=R9lkOjLNzU4']

remaining = [x for x in main_liat if x not in not_found_vids]

print(len(remaining))

v_ids = main['parent_video_id'].unique()
print(len(v_ids))
ds = pd.DataFrame()
for vid in v_ids:
    que = main.query("parent_video_id=='{}'".format(vid))
    video_id = str(que["parent_video_id"].values[0]).split('=')[1]
    questions = que['questions'].values[0]
    start = que['start_time'].values[0]
    end = que['end_time'].values[0]
    subtitles = que['manual_captions'].values[0]
    answer_type = que['answer_type'].values[0]
    subtitle = ''
    if len(subtitles)>1:
        for s in subtitles:
            subtitle += s['transcript'] + '\n'
    else: 
        subtitle = '_'
    for q in questions:
        question = q['question']
        options = q['answers']
        correct_ans_idx = q['correct_index']
        q_id = q['q_id']
        
        choice_string = ''

        choice_string = "0: {}, 1: {}, 2: {}, 3: {}".format(options[0], options[1],options[2],options[3])
        
        ds['q_id'] = q_id
        ds['question'] = question
        ds['answer_type'] = answer_type
        ds['Answers'] = options
        ds['ans_idx'] = correct_ans_idx
        ds['video_id'] = video_id
        ds['start'] = start
        ds['end'] = end
        ds['subtitles'] = subtitle
        
        
       

        if not os.path.isdir('{}/trim/{}{}-opencv'.format(directory_path,q_id,video_id)):
             prompt = run_oic(q_id, video_id, start, end)
             if prompt is not None:
                print(ds.info)
                ds['OIC_context'] = prompt
                formatted_question = question+ 'subtitle:'+str(subtitle) +' Guess the most likely answer among these options: '+choice_string+' Respond only with a single number between 0 and 4. Do not produce any other output.'
                response = run_gpt(prompt, formatted_question)
                ds['OIC_answer'] = str(response)
                ds['OIC_question'] = formatted_question
                count = 0
                while count<2:
                    if len(response)>1:
                        response = run_gpt(prompt, formatted_question) 
                        count+=1
                    else:
                        response = int(response)
                        break
                OIC_answer = response
                if not len(str(OIC_answer)) > 1:
                    if OIC_answer == correct_ans_idx:
                
                        ds['Match'] = 'Correct'
                        print('correct')
                    else:
                        print('wrong')

                        ds['Match'] = 'Wrong'
                else:
                    ds['Match'] = response
                
                print('-'*100)
                print('OIC question: {}'.format(formatted_question))
                print('OIC answer: {}'.format(OIC_answer))
                print('Answer: {}'.format(correct_ans_idx))
                ds.to_csv('LifeQA/datatables/question_answers.csv')
